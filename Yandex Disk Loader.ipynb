# %%
from collections import namedtuple
import time
from urllib.parse import urljoin

from bs4 import BeautifulSoup
import requests

# %%
HOST = "https://cloud-api.yandex.net/v1/"
TOKEN = "y0_AgAAAAAIsQlOAAo5zgAAAADoimgdHQle499aS-aVeG4ejIKf9W2g6ak"

# %%
headers = {
    "Accept": "application/json",
    "Authorization": f"OAuth {TOKEN}",
    "Content-Type": "application/json",    
}

# %% [markdown]
# # Create folders

# %%
create_folder_api_path = "disk/resources"

# %%
params = {
    "path": "/tax-service-opendata"
}
url = urljoin(HOST, create_folder_api_path)

# %%
response = requests.put(url, headers=headers, params=params)
assert response.status_code == 201
# Out:
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# Cell In[43], line 2
#       1 response = requests.put(url, headers=headers, params=params)
# ----> 2 assert response.status_code == 201
#
# AssertionError:

# %%
for folder_name in ("debtam", "paytax", "revexp", "rsmp", "rsmppp", "sshr"):
    folder_path = f"/tax-service-opendata/{folder_name}"
    params = dict(path=folder_path)
    url = urljoin(HOST, create_folder_api_path)
    resp = requests.put(url, headers=headers, params=params)
    assert resp.status_code == 201
    print(f"Created {folder_path}")
    time.sleep(1)
# Out:
# Created /tax-service-opendata/debtam
# Created /tax-service-opendata/paytax
# Created /tax-service-opendata/revexp
# Created /tax-service-opendata/rmsp
# Created /tax-service-opendata/rmsppp
# Created /tax-service-opendata/sshr

# %% [markdown]
# # Upload data

# %%
data_sources = {
    "debtam": "https://www.nalog.gov.ru/opendata/7707329152-debtam/",
    "paytax": "https://www.nalog.gov.ru/opendata/7707329152-paytax/",
    "revexp": "https://www.nalog.gov.ru/opendata/7707329152-revexp/",
    "rsmp": "https://www.nalog.gov.ru/opendata/7707329152-rsmp/",
    "rsmppp": "https://www.nalog.gov.ru/opendata/7707329152-rsmppp/",
    "sshr": "https://www.nalog.gov.ru/opendata/7707329152-sshr2019/",
}

# %%
def parse_page(url):
    # Container for the result
    ParseResult = namedtuple("ParseResult", ["data", "schemas"])
    
    # Get the page source
    print(f"Scraping {url}")
    resp = requests.get(url)
    if resp.status_code != 200:
        print(f"Cannot get the page")
        return None
    
    # Make the soup
    soup = BeautifulSoup(resp.text, "html.parser")
    
    # Get the table of interest
    table = soup.find("table", class_="border_table")
    if table is None:
        print("Cannot find table in data source")
        return None
    
    # Parse table
    rows = table("tr")    
    row_index = {}
    for row in rows:
        cells = row("td")
        if len(cells) != 3:
            continue
        
        number = cells[0].get_text(strip=True)
        if number.isdigit():
            number = int(number)
        else:
            print("Unexpected non-numeric row number")
            continue
        
        name = cells[1].get_text(strip=True)
        value = cells[2]
        
        row_index[number] = dict(name=name, value=value)
    
    # Check whether the table contains all necessary items
    expected_rows = {
        8: "Гиперссылка (URL) на набор",
        10: "Описание структуры набора данных",
        16: "Гиперссылки (URL) на предыдущие релизы набора данных",
        17: "Гиперссылки (URL) на предыдущие версии структуры набора данных",
    }
    for expected_number, expected_name in expected_rows.items():
        name = row_index.get(expected_number, {}).get("name")
        if name != expected_name:
            print("Something is wrong with data source: "
                  f"expected {expected_name} on position {expected_number}, found {name}")
            return None
    
    # Extract URLs of data files and schema files
    data_files, schema_files = [], []
    
    data_links = row_index[8]["value"]("a") + row_index[16]["value"]("a")
    for link in data_links:
        url = link.get("href")
        if url is not None:
            data_files.append(url)
    
    schema_links = row_index[10]["value"]("a") + row_index[17]["value"]("a")
    for link in schema_links:
        url = link.get("href")
        if url is not None:
            schema_files.append(url)
    
    print(f"Found {len(data_files)} data link(s) and {len(schema_files)} schema link(s)")
    
    return ParseResult(data_files, schema_files)

# %%
def make_yd_dir(path):
    print(f"Trying to create {path} on Yandex Disk")
    
    create_folder_api_path = "disk/resources"
    headers = {
        "Accept": "application/json",
        "Authorization": f"OAuth {TOKEN}",
        "Content-Type": "application/json",    
    }
    params = {
        "path": path,
    }
    url = urljoin(HOST, create_folder_api_path)
    
    resp = requests.put(url, headers=headers, params=params)
    
    if resp.status_code == 201:
        print("Folder created")
    elif resp.status_code == 409:
        print("Folder exists")
    else:
        print("Error while creating folder, see details below")
        print(resp.json())
        print()

# %%
def get_existing_files(path):
    print(f"Trying to get items list for {path}")
    result = []
    create_folder_api_path = "disk/resources"
    headers = {
        "Accept": "application/json",
        "Authorization": f"OAuth {TOKEN}",
        "Content-Type": "application/json",    
    }
    params = {
        "path": path,
        "fields": "_embedded.items.path,_embedded.items.type",
        "limit": 500,
    }
    url = urljoin(HOST, create_folder_api_path)
    
    resp = requests.get(url, headers=headers, params=params)
    if resp.status_code != 200:
        print("Cannot get path medatata, see error message below")
        print(resp.json())
        print()
        return result

    for item in resp.json().get("_embedded", {}).get("items", []):
        if item.get("type") == "file":
            result.append(item.get("path"))
    
    print(f"Found {len(result)} files")
    
    return result

# %%
def check_existing(link, existing_files):
    # Checking by name (the last part of link or path)
    _, _, link_name = link.rpartition("/")
    for existing_file in existing_files:
        _, _, file_name = existing_file.rpartition("/")
        if link_name == file_name:
            return True
        
    return False

# %%
def upload_file(file_url, path):
    UploadResult = namedtuple("UploadResult", ["url", "info"])
    print(f"Uploading {file_url} to {path}")
    
    _, _, file_name = file_url.rpartition("/")
    dest = f"{path}/{file_name}"
    
    upload_api_path = "disk/resources/upload"
    headers = {
        "Accept": "application/json",
        "Authorization": f"OAuth {TOKEN}",
        "Content-Type": "application/json",    
    }
    params = {
        "url": file_url,
        "path": dest,
    }
    url = urljoin(HOST, upload_api_path)
    
    resp = requests.post(url, headers=headers, params=params)
    if resp.status_code == 202:
        print("Upload task created successfully")
        info = resp.json().get("href")
    else:
        print("Error while creating upload task")
        print(resp.json())
        info = None
    
    result = UploadResult(file_url, info)
    
    return result

# %%
def check_status(info_url):
    if info_url is None:
        return "cannot_check"
    
    headers = {
        "Accept": "application/json",
        "Authorization": f"OAuth {TOKEN}",
        "Content-Type": "application/json",    
    }
    
    try:
        resp = requests.get(info_url, headers=headers, timeout=5)
    except Exception:
        return "check_error"
    
    if resp.status_code == 200:
        return resp.json().get("status")
    else:
        return "check_error"

# %%
def process_data_source(name, url):
    # Get links to files
    links = parse_page(url)
    if links is None:
        return None
    
    # Destination on Yandex Disk
    data_path = f"/tax-service-opendata/{name}/data"
    schemas_path = f"/tax-service-opendata/{name}/schemas"
    
    # Make dirs if not exist
    make_yd_dir(data_path)
    make_yd_dir(schemas_path)
    
    status = {}
    # Upload new data files
    existing_data_files = get_existing_files(data_path)
    for link in links.data:
        if check_existing(link, existing_data_files):
            continue
        result = upload_file(link, data_path)
        status[result.url] = result.info
    
    # Upload new schema files
    existing_schema_files = get_existing_files(schemas_path)
    for link in links.schemas:
        if check_existing(link, existing_schema_files):
            continue
        result = upload_file(link, schemas_path)
        status[result.url] = result.info
    
    return status

# %%
stats = {}
for name, url in data_sources.items():
    result = process_data_source(name, url)
    stats.update(result)
# Out:
# Scraping https://www.nalog.gov.ru/opendata/7707329152-debtam/
# Found 12 data link(s) and 1 schema link(s)
# Trying to create /tax-service-opendata/debtam/data on Yandex Disk
# Folder exists
# Trying to create /tax-service-opendata/debtam/schemas on Yandex Disk
# Folder exists
# Trying to get items list for /tax-service-opendata/debtam/data
# Found 11 files
# Uploading https://file.nalog.ru/opendata/7707329152-debtam/data-20211201-structure-20181201.zip to /tax-service-opendata/debtam/data
# Upload task created successfully
# Trying to get items list for /tax-service-opendata/debtam/schemas
# Found 1 files
# Scraping https://www.nalog.gov.ru/opendata/7707329152-paytax/
# Found 12 data link(s) and 1 schema link(s)
# Trying to create /tax-service-opendata/paytax/data on Yandex Disk
# Folder exists
# Trying to create /tax-service-opendata/paytax/schemas on Yandex Disk
# Folder exists
# Trying to get items list for /tax-service-opendata/paytax/data
# Found 11 files
# Uploading https://file.nalog.ru/opendata/7707329152-paytax/data-20221001-structure-20180110.zip to /tax-service-opendata/paytax/data
# Upload task created successfully
# Trying to get items list for /tax-service-opendata/paytax/schemas
# Found 1 files
# Scraping https://www.nalog.gov.ru/opendata/7707329152-revexp/
# Found 15 data link(s) and 1 schema link(s)
# Trying to create /tax-service-opendata/revexp/data on Yandex Disk
# Folder exists
# Trying to create /tax-service-opendata/revexp/schemas on Yandex Disk
# Folder exists
# Trying to get items list for /tax-service-opendata/revexp/data
# Found 14 files
# Uploading https://file.nalog.ru/opendata/7707329152-revexp/data-20230430-structure-20180110.zip to /tax-service-opendata/revexp/data
# Upload task created successfully
# Trying to get items list for /tax-service-opendata/revexp/schemas
# Found 1 files
# Scraping https://www.nalog.gov.ru/opendata/7707329152-rsmp/
# Found 84 data link(s) and 5 schema link(s)
# Trying to create /tax-service-opendata/rsmp/data on Yandex Disk
# Folder exists
# Trying to create /tax-service-opendata/rsmp/schemas on Yandex Disk
# Folder exists
# Trying to get items list for /tax-service-opendata/rsmp/data
# Found 73 files
# Uploading https://file.nalog.ru/opendata/7707329152-rsmp/data-10072023-structure-10062023.zip  to /tax-service-opendata/rsmp/data
# Upload task created successfully
# Uploading https://file.nalog.ru/opendata/7707329152-rsmp/data-10052023-structure-10032022.zip  to /tax-service-opendata/rsmp/data
# Upload task created successfully
# Uploading https://file.nalog.ru/opendata/7707329152-rsmp/data-10032023-structure-10032022.zip  to /tax-service-opendata/rsmp/data
# Upload task created successfully
# Uploading https://file.nalog.ru/opendata/7707329152-rsmp/data-10122022-structure-10032022.zip  to /tax-service-opendata/rsmp/data
# Upload task created successfully
# Uploading https://file.nalog.ru/opendata/7707329152-rsmp/data-10092022-structure-10032022.zip  to /tax-service-opendata/rsmp/data
# Upload task created successfully
# Uploading https://file.nalog.ru/opendata/7707329152-rsmp/data-10082022-structure-10032022.zip  to /tax-service-opendata/rsmp/data
# Upload task created successfully
# Uploading https://file.nalog.ru/opendata/7707329152-rsmp/data-10072022-structure-10032022.zip  to /tax-service-opendata/rsmp/data
# Upload task created successfully
# Uploading https://file.nalog.ru/opendata/7707329152-rsmp/data-10022022-structure-10082021.zip  to /tax-service-opendata/rsmp/data
# Upload task created successfully
# Uploading https://file.nalog.ru/opendata/7707329152-rsmp/data-10122021-structure-10082021.zip  to /tax-service-opendata/rsmp/data
# Upload task created successfully
# Uploading https://file.nalog.ru/opendata/7707329152-rsmp/data-10112021-structure-10082021.zip  to /tax-service-opendata/rsmp/data
# Upload task created successfully
# Uploading https://file.nalog.ru/opendata/7707329152-rsmp/data-10092020-structure-15052020.zip to /tax-service-opendata/rsmp/data
# Upload task created successfully
# Trying to get items list for /tax-service-opendata/rsmp/schemas
# Found 3 files
# Uploading https://file.nalog.ru/opendata/7707329152-rsmp/structure-10032022.xsd to /tax-service-opendata/rsmp/schemas
# Upload task created successfully
# Uploading https://file.nalog.ru/opendata/7707329152-rsmp/structure-10082021.xsd to /tax-service-opendata/rsmp/schemas
# Upload task created successfully
# Scraping https://www.nalog.gov.ru/opendata/7707329152-rsmppp/
# Found 32 data link(s) and 4 schema link(s)
# Trying to create /tax-service-opendata/rsmppp/data on Yandex Disk
# Folder exists
# Trying to create /tax-service-opendata/rsmppp/schemas on Yandex Disk
# Folder exists
# Trying to get items list for /tax-service-opendata/rsmppp/data
# Found 31 files
# Uploading https://file.nalog.ru/opendata/7707329152-rsmppp/data-20210115-structure-20201220.zip to /tax-service-opendata/rsmppp/data
# Upload task created successfully
# Trying to get items list for /tax-service-opendata/rsmppp/schemas
# Found 3 files
# Uploading https://file.nalog.ru/opendata/7707329152-rsmppp/structure-20201220.xsd to /tax-service-opendata/rsmppp/schemas
# Upload task created successfully
# Scraping https://www.nalog.gov.ru/opendata/7707329152-sshr2019/
# Found 18 data link(s) and 1 schema link(s)
# Trying to create /tax-service-opendata/sshr/data on Yandex Disk
# Folder exists
# Trying to create /tax-service-opendata/sshr/schemas on Yandex Disk
# Folder exists
# Trying to get items list for /tax-service-opendata/sshr/data
# Found 17 files
# Uploading https://file.nalog.ru/opendata/7707329152-sshr2019/data-20210408-structure-20180801.zip to /tax-service-opendata/sshr/data
# Upload task created successfully
# Trying to get items list for /tax-service-opendata/sshr/schemas
# Found 1 files

# %%
for url, info_url in stats.items():
    if info_url == "task_create_error":
        continue
    print(f"{url}: {check_status(info_url)}")
# Out:
# https://file.nalog.ru/opendata/7707329152-debtam/data-20211201-structure-20181201.zip: failed
# https://file.nalog.ru/opendata/7707329152-paytax/data-20221001-structure-20180110.zip: failed
# https://file.nalog.ru/opendata/7707329152-revexp/data-20230430-structure-20180110.zip: failed
# https://file.nalog.ru/opendata/7707329152-rsmp/data-10072023-structure-10062023.zip : failed
# https://file.nalog.ru/opendata/7707329152-rsmp/data-10052023-structure-10032022.zip : failed
# https://file.nalog.ru/opendata/7707329152-rsmp/data-10032023-structure-10032022.zip : failed
# https://file.nalog.ru/opendata/7707329152-rsmp/data-10122022-structure-10032022.zip : failed
# https://file.nalog.ru/opendata/7707329152-rsmp/data-10092022-structure-10032022.zip : failed
# https://file.nalog.ru/opendata/7707329152-rsmp/data-10082022-structure-10032022.zip : failed
# https://file.nalog.ru/opendata/7707329152-rsmp/data-10072022-structure-10032022.zip : failed
# https://file.nalog.ru/opendata/7707329152-rsmp/data-10022022-structure-10082021.zip : failed
# https://file.nalog.ru/opendata/7707329152-rsmp/data-10122021-structure-10082021.zip : failed
# https://file.nalog.ru/opendata/7707329152-rsmp/data-10112021-structure-10082021.zip : failed
# https://file.nalog.ru/opendata/7707329152-rsmp/data-10092020-structure-15052020.zip: failed
# https://file.nalog.ru/opendata/7707329152-rsmp/structure-10032022.xsd: failed
# https://file.nalog.ru/opendata/7707329152-rsmp/structure-10082021.xsd: failed
# https://file.nalog.ru/opendata/7707329152-rsmppp/data-20210115-structure-20201220.zip: failed
# https://file.nalog.ru/opendata/7707329152-rsmppp/structure-20201220.xsd: failed
# https://file.nalog.ru/opendata/7707329152-sshr2019/data-20210408-structure-20180801.zip: failed
