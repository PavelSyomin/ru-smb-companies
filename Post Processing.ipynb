# %%
from fuzzywuzzy import fuzz, process
import numpy as np
import pandas as pd
import tqdm

# %%
pd.set_option("display.max_columns", None)
# %precision 3
# Out:
# '%.3f'

# %%
rsmp = pd.read_csv("rsmp/csv/data.csv")
settlements = pd.read_csv("settlements_12032021/data.csv")
cities_base = pd.read_csv("city.csv")
cities_additional = pd.read_csv("cities_additional.csv")
socr = pd.read_csv("socrbase.csv")

cities = pd.concat((cities_base, cities_additional))
rsmp = rsmp.reset_index(names="id")

# %%
socr_full_to_full = socr[["name_full", "name_full"]]
socr_full_to_full.columns = ("name", "name_full")
socr_full_to_full.head(3)
# Out:
#                  name           name_full
# 0    Автономный округ    Автономный округ
# 1  Автономная область  Автономная область
# 2               Город               Город

# %%
socr_without_dot = socr.loc[~socr["name"].str.endswith("."), ["name", "name_full"]]
socr_without_dot["name"] = socr_without_dot["name"] + "."
socr_without_dot.head(3)
# Out:
#     name           name_full
# 0    АО.    Автономный округ
# 1  Аобл.  Автономная область
# 2     г.               Город

# %%
abbr_to_full = pd.concat(
    (socr[["name", "name_full"]], socr_full_to_full, socr_without_dot)
)
abbr_to_full = abbr_to_full.apply(lambda x: x.str.upper())
abbr_to_full.drop_duplicates("name", inplace=True)
abbr_to_full.head(10)
# Out:
#       name           name_full
# 0       АО    АВТОНОМНЫЙ ОКРУГ
# 1     АОБЛ  АВТОНОМНАЯ ОБЛАСТЬ
# 2        Г               ГОРОД
# 3     КРАЙ                КРАЙ
# 4      ОБЛ             ОБЛАСТЬ
# 5     РЕСП          РЕСПУБЛИКА
# 6    ОКРУГ               ОКРУГ
# 7  ЧУВАШИЯ             ЧУВАШИЯ
# 8   А.ОБЛ.  АВТОНОМНАЯ ОБЛАСТЬ
# 9   А.ОКР.    АВТОНОМНЫЙ ОКРУГ

# %%
address_cols = [
    "region_name",
    "region_type",
    "district_name",
    "district_type",
    "city_name",
    "city_type",
    "settlement_name",
    "settlement_type",
]
addresses = rsmp.loc[:, ["id"] + address_cols]
addresses.head(2)
# Out:
#    id   region_name region_type district_name district_type city_name  \
# 0   0  БАШКОРТОСТАН  РЕСПУБЛИКА           NaN           NaN       УФА
# 1   1  БАШКОРТОСТАН  РЕСПУБЛИКА           NaN           NaN       УФА
#
#   city_type settlement_name settlement_type
# 0     ГОРОД             NaN             NaN
# 1     ГОРОД             NaN             NaN

# %%
addr_count = len(addresses)
addr_count
# Out:
# 172095

# %%
addresses.isna().sum()
# Out:
# id                      0
# region_name            20
# region_type            20
# district_name      143985
# district_type      143985
# city_name           57279
# city_type           57279
# settlement_name    151398
# settlement_type    151398
# dtype: int64

# %%
def join_name_and_type(name, type_):
    if pd.isna(name) or pd.isna(type_):
        return np.nan
    
    prepend_types = (
        "ГОРОД", "РЕСПУБЛИКА", "ПОСЕЛОК", "ПОСЕЛОК ГОРОДСКОГО ТИПА", "РАБОЧИЙ ПОСЕЛОК"
    )
    prepend = type_ in prepend_types
    if prepend:
        return f"{type_} {name}"
    
    return f"{name} {type_}"

# %%
def preprocess_text_column(c):
    return c.str.upper().replace("Ё", "Е")

# %%
for option in ("region", "district", "city", "settlement"):
    target_col = f"{option}_type"
    addresses = addresses.merge(
        abbr_to_full,
        how="left",
        left_on=target_col,
        right_on="name",
    )
    addresses[target_col] = addresses["name_full"]
    addresses.drop(columns=abbr_to_full.columns, inplace=True)
    assert len(addresses) == addr_count, (
        f"Number of addresses must not change, but for {target_col} "
        f"the size has changed: {addr_count} -> {len(addresses)}"
    )
    
    parts = [f"{option}_name", f"{option}_type"]
    addresses[option] = addresses[parts].apply(
        lambda row: join_name_and_type(row[parts[0]], row[parts[1]]),
        axis=1
    )
addresses.isna().sum()
# Out:
# id                      0
# region_name            20
# region_type            20
# district_name      143985
# district_type      143985
# city_name           57279
# city_type           57279
# settlement_name    151398
# settlement_type    151403
# region                 20
# district           143985
# city                57279
# settlement         151403
# dtype: int64

# %%
unique_region_names = addresses["region_name"].dropna().unique()
unique_regions_in_cities = cities["region"].dropna().unique()
region_names_to_cities = pd.DataFrame({
    "region_name": unique_region_names,
    "region_cities": [
        process.extractOne(region_name, unique_regions_in_cities)[0].upper()
        for region_name in unique_region_names
    ]
})
region_names_to_cities.head(3)
# Out:
#     region_name region_cities
# 0  БАШКОРТОСТАН  БАШКОРТОСТАН
# 1       БУРЯТИЯ       БУРЯТИЯ
# 2      ДАГЕСТАН      ДАГЕСТАН

# %%
unique_regions = addresses["region"].dropna().unique()
unique_regions_in_settlements = settlements["region"].dropna().unique()
regions_to_settlements = pd.DataFrame({
    "region": unique_regions,
    "region_settlements": [
        process.extractOne(
            region_name,
            unique_regions_in_settlements,
            scorer=fuzz.token_set_ratio
        )[0].upper()
        for region_name in unique_regions
    ]
})
regions_to_settlements.head(3)
# Out:
#                     region       region_settlements
# 0  РЕСПУБЛИКА БАШКОРТОСТАН  РЕСПУБЛИКА БАШКОРТОСТАН
# 1       РЕСПУБЛИКА БУРЯТИЯ       РЕСПУБЛИКА БУРЯТИЯ
# 2      РЕСПУБЛИКА ДАГЕСТАН      РЕСПУБЛИКА ДАГЕСТАН

# %%
addresses = addresses.merge(region_names_to_cities, how="left", on="region_name")
addresses = addresses.merge(regions_to_settlements, how="left", on="region")
addresses.iloc[:, 1:] = addresses.iloc[:, 1:].apply(preprocess_text_column)
assert len(addresses) == addr_count
addresses.head(2)
# Out:
#    id   region_name region_type district_name district_type city_name  \
# 0   0  БАШКОРТОСТАН  РЕСПУБЛИКА           NaN           NaN       УФА
# 1   1  БАШКОРТОСТАН  РЕСПУБЛИКА           NaN           NaN       УФА
#
#   city_type settlement_name settlement_type                   region district  \
# 0     ГОРОД             NaN             NaN  РЕСПУБЛИКА БАШКОРТОСТАН      NaN
# 1     ГОРОД             NaN             NaN  РЕСПУБЛИКА БАШКОРТОСТАН      NaN
#
#         city settlement region_cities       region_settlements
# 0  ГОРОД УФА        NaN  БАШКОРТОСТАН  РЕСПУБЛИКА БАШКОРТОСТАН
# 1  ГОРОД УФА        NaN  БАШКОРТОСТАН  РЕСПУБЛИКА БАШКОРТОСТАН

# %%
std_c = cities.reset_index(names="id")[["id", "region", "area", "city", "settlement"]]
std_c.iloc[:, 1:] = std_c.iloc[:, 1:].apply(preprocess_text_column)
std_c.head(3)
# Out:
#    id  region area           city settlement
# 0   0  АДЫГЕЯ  NaN       АДЫГЕЙСК        NaN
# 1   1  АДЫГЕЯ  NaN         МАЙКОП        NaN
# 2   2   АЛТАЙ  NaN  ГОРНО-АЛТАЙСК        NaN

# %%
std_s = settlements.loc[:, ["id", "region", "municipality", "settlement", "type"]]
std_s["type"] = std_s["type"].str.upper()
std_s = std_s.merge(
    abbr_to_full,
    how="left",
    left_on="type",
    right_on="name"
)
std_s["type"] = std_s["name_full"]
std_s.drop(columns=abbr_to_full.columns, inplace=True)
std_s.iloc[:, 1:] = std_s.iloc[:, 1:].apply(preprocess_text_column)
std_s.head(3)
# Out:
#    id             region           municipality  settlement     type
# 0   0  ОРЛОВСКАЯ ОБЛАСТЬ             БОЛХОВСКИЙ  КОЛОНТАЕВА  ДЕРЕВНЯ
# 1   1    РЕСПУБЛИКА КРЫМ                 АЛУШТА     ПУШКИНО     СЕЛО
# 2   2   ЛИПЕЦКАЯ ОБЛАСТЬ  ЛЕВ-ТОЛСТОВСКИЙ РАЙОН    БАРЯТИНО     СЕЛО

# %%
merge_options = [
    {
        "name": "Settlements by all parts with full district name",
        "addresses": ["region_settlements", "district", "settlement_name", "settlement_type"],
        "standard": ["region", "municipality", "settlement", "type"],
        "type": "settlements"
    },
    {
        "name": "Settlements by all parts with partial district name (no type)",
        "addresses": ["region_settlements", "district_name", "settlement_name", "settlement_type"],
        "standard": ["region", "municipality", "settlement", "type"],
        "type": "settlements",
    },
    {
        "name": "Settlements by all parts with full city name",
        "addresses": ["region_settlements", "city", "settlement_name", "settlement_type"],
        "standard": ["region", "municipality", "settlement", "type"],
        "type": "settlements",
    },
    {
        "name": "Settlements by all parts with partial city name (no type)",
        "addresses": ["region_settlements", "city_name", "settlement_name", "settlement_type"],
        "standard": ["region", "municipality", "settlement", "type"],
        "type": "settlements",
    },
    {
        "name": "Settlements by all parts except for type with full district name",
        "addresses": ["region_settlements", "district", "settlement_name"],
        "standard": ["region", "municipality", "settlement"],
        "type": "settlements",
    },
    {
        "name": "Settlements by all parts except for type with partial district name",
        "addresses": ["region_settlements", "district_name", "settlement_name"],
        "standard": ["region", "municipality", "settlement"],
        "type": "settlements",
    },
    {
        "name": "Settlements by all parts except for type with full city name",
        "addresses": ["region_settlements", "city", "settlement_name"],
        "standard": ["region", "municipality", "settlement"],
        "type": "settlements",
    },
    {
        "name": "Settlements by all parts except for type with partial city name",
        "addresses": ["region_settlements", "city_name", "settlement_name"],
        "standard": ["region", "municipality", "settlement"],
        "type": "settlements",
    },
    {
        "name": "Settlements by region and settlement with type",
        "addresses": ["region_settlements", "settlement_name", "settlement_type"],
        "standard": ["region", "settlement", "type"],
        "type": "settlements",
    },
    {
        "name": "Settlements by region and settlement without type",
        "addresses": ["region_settlements", "settlement_name"],
        "standard": ["region", "settlement"],
        "type": "settlements",
    },
    {
        "name": "Cities by all parts",
        "addresses": ["region_cities", "district_name", "city_name", "settlement_name"],
        "standard": ["region", "area", "city", "settlement"],
        "type": "cities",
    },
    {
        "name": "Cities by all parts except for settlements",
        "addresses": ["region_cities", "district_name", "city_name"],
        "standard": ["region", "area", "city"],
        "type": "cities",
    },
    {
        "name": "Cities by region and city",
        "addresses": ["region_cities", "city_name"],
        "standard": ["region", "city"],
        "type": "cities",
    },
    {
        "name": "Cities by region and district-as-city",
        "addresses": ["region_cities", "city_name"],
        "standard": ["region", "area"],
        "type": "cities",
    },    
]

# %%
mappings = []
rest = addresses
orig_cols = addresses.columns
for option in merge_options:
    name = option["name"]
    left_cols = option["addresses"]
    right_cols = option["standard"]
    type_ = option["type"]

    to_merge = rest[orig_cols]
    standard = std_c.copy() if type_ == "cities" else std_s.copy()
    standard.drop_duplicates(subset=right_cols, keep=False, inplace=True)
    standard.rename(columns={"id": "geo_id"}, inplace=True)
    #print(to_merge.columns)
    #print(standard.columns)
    #print(standard.shape)
    
    size_before = len(to_merge)
    merged = to_merge.merge(
        standard,
        how="left",
        left_on=left_cols,
        right_on=right_cols,
        suffixes=("", "_x")
    )
    #print(len(merged))
    
    size_after = len(merged)
    assert size_before == size_after
    
    mapped = merged.loc[merged["geo_id"].notna(), ["id", "geo_id"]]
    mapped["type"] = type_[0]
    if len(mapped) > 0:
        mappings.append(mapped)
        
    rest = merged.loc[merged["geo_id"].isna()]
    
    print(f"Option {name}: found {len(mapped)} matches, {len(rest)} records left")
# Out:
# Option Settlements by all parts with full district name: found 7376 matches, 164719 records left
# Option Settlements by all parts with partial district name (no type): found 3137 matches, 161582 records left
# Option Settlements by all parts with full city name: found 139 matches, 161443 records left
# Option Settlements by all parts with partial city name (no type): found 491 matches, 160952 records left
# Option Settlements by all parts except for type with full district name: found 1497 matches, 159455 records left
# Option Settlements by all parts except for type with partial district name: found 638 matches, 158817 records left
# Option Settlements by all parts except for type with full city name: found 191 matches, 158626 records left
# Option Settlements by all parts except for type with partial city name: found 198 matches, 158428 records left
# Option Settlements by region and settlement with type: found 2566 matches, 155862 records left
# Option Settlements by region and settlement without type: found 1175 matches, 154687 records left
# Option Cities by all parts: found 146311 matches, 8376 records left
# Option Cities by all parts except for settlements: found 1664 matches, 6712 records left
# Option Cities by region and city: found 2596 matches, 4116 records left
# Option Cities by region and district-as-city: found 167 matches, 3949 records left

# %%
rest
# Out:
#           id         region_name region_type district_name district_type  \
# 0        148          МОСКОВСКАЯ     ОБЛАСТЬ           NaN           NaN
# 1        151          МОСКОВСКАЯ     ОБЛАСТЬ           NaN           NaN
# 2        153          МОСКОВСКАЯ     ОБЛАСТЬ           NaN           NaN
# 3        531  ЛУГАНСКАЯ НАРОДНАЯ  РЕСПУБЛИКА           NaN           NaN
# 4        532  ЛУГАНСКАЯ НАРОДНАЯ  РЕСПУБЛИКА   ЛУТУГИНСКИЙ         РАЙОН
# ...      ...                 ...         ...           ...           ...
# 4111  171852          МОСКОВСКАЯ     ОБЛАСТЬ    ЩЕЛКОВСКИЙ         РАЙОН
# 4112  171853          МОСКОВСКАЯ     ОБЛАСТЬ           NaN           NaN
# 4113  171881       НОВОСИБИРСКАЯ     ОБЛАСТЬ   ИСКИТИМСКИЙ         РАЙОН
# 4114  171952         САРАТОВСКАЯ     ОБЛАСТЬ  ДЕРГАЧЕВСКИЙ         РАЙОН
# 4115  172018         ЧЕЛЯБИНСКАЯ     ОБЛАСТЬ    СОСНОВСКИЙ         РАЙОН
#
#           city_name        city_type   settlement_name settlement_type  \
# 0           ДМИТРОВ            ГОРОД               NaN             NaN
# 1          ОДИНЦОВО            ГОРОД               NaN             NaN
# 2     ОРЕХОВО-ЗУЕВО            ГОРОД               NaN             NaN
# 3          ЛУТУГИНО            ГОРОД               NaN             NaN
# 4          ЛУТУГИНО            ГОРОД               NaN             NaN
# ...             ...              ...               ...             ...
# 4111        ЩЕЛКОВО            ГОРОД               NaN             NaN
# 4112      ШАХОВСКАЯ  РАБОЧИЙ ПОСЕЛОК               NaN             NaN
# 4113            NaN              NaN               NaN             NaN
# 4114            NaN              NaN         ВОСТОЧНЫЙ         ПОСЕЛОК
# 4115            NaN              NaN  СМОЛИНО Ж-Д. СТ.         ПОСЕЛОК
#
#                              region            district  \
# 0                МОСКОВСКАЯ ОБЛАСТЬ                 NaN
# 1                МОСКОВСКАЯ ОБЛАСТЬ                 NaN
# 2                МОСКОВСКАЯ ОБЛАСТЬ                 NaN
# 3     РЕСПУБЛИКА ЛУГАНСКАЯ НАРОДНАЯ                 NaN
# 4     РЕСПУБЛИКА ЛУГАНСКАЯ НАРОДНАЯ   ЛУТУГИНСКИЙ РАЙОН
# ...                             ...                 ...
# 4111             МОСКОВСКАЯ ОБЛАСТЬ    ЩЕЛКОВСКИЙ РАЙОН
# 4112             МОСКОВСКАЯ ОБЛАСТЬ                 NaN
# 4113          НОВОСИБИРСКАЯ ОБЛАСТЬ   ИСКИТИМСКИЙ РАЙОН
# 4114            САРАТОВСКАЯ ОБЛАСТЬ  ДЕРГАЧЕВСКИЙ РАЙОН
# 4115            ЧЕЛЯБИНСКАЯ ОБЛАСТЬ    СОСНОВСКИЙ РАЙОН
#
#                            city                settlement  region_cities  \
# 0                 ГОРОД ДМИТРОВ                       NaN     МОСКОВСКАЯ
# 1                ГОРОД ОДИНЦОВО                       NaN     МОСКОВСКАЯ
# 2           ГОРОД ОРЕХОВО-ЗУЕВО                       NaN     МОСКОВСКАЯ
# 3                ГОРОД ЛУТУГИНО                       NaN     КУРГАНСКАЯ
# 4                ГОРОД ЛУТУГИНО                       NaN     КУРГАНСКАЯ
# ...                         ...                       ...            ...
# 4111              ГОРОД ЩЕЛКОВО                       NaN     МОСКОВСКАЯ
# 4112  РАБОЧИЙ ПОСЕЛОК ШАХОВСКАЯ                       NaN     МОСКОВСКАЯ
# 4113                        NaN                       NaN  НОВОСИБИРСКАЯ
# 4114                        NaN         ПОСЕЛОК ВОСТОЧНЫЙ    САРАТОВСКАЯ
# 4115                        NaN  ПОСЕЛОК СМОЛИНО Ж-Д. СТ.    ЧЕЛЯБИНСКАЯ
#
#          region_settlements  geo_id region_x area city_x settlement_x
# 0        МОСКОВСКАЯ ОБЛАСТЬ     NaN      NaN  NaN    NaN          NaN
# 1        МОСКОВСКАЯ ОБЛАСТЬ     NaN      NaN  NaN    NaN          NaN
# 2        МОСКОВСКАЯ ОБЛАСТЬ     NaN      NaN  NaN    NaN          NaN
# 3           РЕСПУБЛИКА КРЫМ     NaN      NaN  NaN    NaN          NaN
# 4           РЕСПУБЛИКА КРЫМ     NaN      NaN  NaN    NaN          NaN
# ...                     ...     ...      ...  ...    ...          ...
# 4111     МОСКОВСКАЯ ОБЛАСТЬ     NaN      NaN  NaN    NaN          NaN
# 4112     МОСКОВСКАЯ ОБЛАСТЬ     NaN      NaN  NaN    NaN          NaN
# 4113  НОВОСИБИРСКАЯ ОБЛАСТЬ     NaN      NaN  NaN    NaN          NaN
# 4114    САРАТОВСКАЯ ОБЛАСТЬ     NaN      NaN  NaN    NaN          NaN
# 4115    ЧЕЛЯБИНСКАЯ ОБЛАСТЬ     NaN      NaN  NaN    NaN          NaN
#
# [3949 rows x 20 columns]

# %%
mappings = []
rest = addresses
orig_cols = addresses.columns
for option in merge_options:
    name = option["name"]
    left_cols = option["addresses"]
    right_cols = option["standard"]
    type_ = option["type"]

    to_merge = rest[orig_cols]
    standard = std_c.copy() if type_ == "cities" else std_s.copy()
    standard.drop_duplicates(subset=right_cols, keep=False, inplace=True)
    standard.rename(columns={"id": "geo_id"}, inplace=True)
    #print(to_merge.columns)
    #print(standard.columns)
    #print(standard.shape)
    
    size_before = len(to_merge)
    merged = to_merge.merge(
        standard,
        how="left",
        left_on=left_cols,
        right_on=right_cols,
        suffixes=("", "_x")
    )
    #print(len(merged))
    
    size_after = len(merged)
    assert size_before == size_after
    
    mapped = merged.loc[merged["geo_id"].notna(), ["id", "geo_id"]]
    mapped["type"] = type_[0]
    if len(mapped) > 0:
        mappings.append(mapped)
        
    rest = merged.loc[merged["geo_id"].isna()]
    
    print(f"Option {name}: found {len(mapped)} matches, {len(rest)} records left")

# %%
mappings
# Out:
# [            id  id_settlements
#  20          20         70137.0
#  21          21        142764.0
#  41          41          9048.0
#  63          63        109043.0
#  64          64         65608.0
#  ...        ...             ...
#  172020  172020         30374.0
#  172025  172025        131816.0
#  172026  172026        131816.0
#  172086  172086         99905.0
#  172089  172089         99905.0
#
#  [7376 rows x 2 columns],
#              id  id_settlements
#  8            8         39110.0
#  441        441        145456.0
#  445        445         38655.0
#  454        454         19266.0
#  496        496         29955.0
#  ...        ...             ...
#  171825  171825        118429.0
#  171921  171921        137887.0
#  171923  171923         68188.0
#  172001  172001           366.0
#  172031  172031         79542.0
#
#  [3137 rows x 2 columns]]

# %%
join_cols = ["region_for_join", "district_for_join", "city_for_join", "settlement_for_join"]
selected_cols = ["region_name_cities", "district_name", "city_name", "settlement_name"]
rsmp[join_cols] = rsmp[selected_cols].apply(lambda x: x.str.replace("Ё", "Е").str.upper())
rsmp.head(2)
# Out:
#    index  kind  category  ind_tin  ind_number first_name last_name patronymic  \
# 0      0     1         1      NaN         NaN        NaN       NaN        NaN
# 1      1     1         1      NaN         NaN        NaN       NaN        NaN
#
#                                             org_name org_short_name  \
# 0  ОБЩЕСТВО С ОГРАНИЧЕННОЙ ОТВЕТСТВЕННОСТЬЮ "АВАН...  ООО "АВАНТАЖ"
# 1  ОБЩЕСТВО С ОГРАНИЧЕННОЙ ОТВЕТСТВЕННОСТЬЮ "АКЦЕНТ"   ООО "АКЦЕНТ"
#
#        org_tin  org_number  region_code   region_name region_type  \
# 0  273080245.0         NaN            2  БАШКОРТОСТАН  РЕСПУБЛИКА
# 1  276115295.0         NaN            2  БАШКОРТОСТАН  РЕСПУБЛИКА
#
#   district_name district_type city_name city_type settlement_name  \
# 0           NaN           NaN       УФА     ГОРОД             NaN
# 1           NaN           NaN       УФА     ГОРОД             NaN
#
#   settlement_type  activity_code_main  start_date    end_date  \
# 0             NaN                69.1  2017-04-10         NaN
# 1             NaN                69.1  2016-12-10  2022-03-10
#
#   region_type_norm district_type_norm city_type_norm settlement_type_norm  \
# 0       Республика                NaN          Город                  NaN
# 1       Республика                NaN          Город                  NaN
#
#   region_name_cities    region_name_with_type  region_name_settlements  \
# 0       Башкортостан  БАШКОРТОСТАН Республика  Республика Башкортостан
# 1       Башкортостан  БАШКОРТОСТАН Республика  Республика Башкортостан
#
#   region_for_join district_for_join city_for_join settlement_for_join
# 0    БАШКОРТОСТАН               NaN           УФА                 NaN
# 1    БАШКОРТОСТАН               NaN           УФА                 NaN

# %%
selected_cols = ["region", "area", "city", "settlement"]
cities[join_cols] = cities[selected_cols].apply(lambda x: x.str.upper().str.replace("Ё", "Е"))
cities["id"] = range(0, cities.shape[0])
cities_for_join = cities[["id"] + join_cols]
cities_for_join.head(2)
# Out:
#    id region_for_join district_for_join city_for_join settlement_for_join
# 0   0          АДЫГЕЯ               NaN      АДЫГЕЙСК                 NaN
# 1   1          АДЫГЕЯ               NaN        МАЙКОП                 NaN

# %%
cities_for_join.shape
# Out:
# (1129, 5)

# %%
merged_1 = rsmp.merge(
    cities_for_join,
    how="left",
    on=join_cols
)
merged_1.rename(columns={"id": "id_c1"}, inplace=True)
assert merged_1.shape[0] == rsmp_nrows

# %%
merged_1.shape
# Out:
# (172095, 36)

# %%
merged_1.head(2)
# Out:
#    index  kind  category  ind_tin  ind_number first_name last_name patronymic  \
# 0      0     1         1      NaN         NaN        NaN       NaN        NaN
# 1      1     1         1      NaN         NaN        NaN       NaN        NaN
#
#                                             org_name org_short_name  \
# 0  ОБЩЕСТВО С ОГРАНИЧЕННОЙ ОТВЕТСТВЕННОСТЬЮ "АВАН...  ООО "АВАНТАЖ"
# 1  ОБЩЕСТВО С ОГРАНИЧЕННОЙ ОТВЕТСТВЕННОСТЬЮ "АКЦЕНТ"   ООО "АКЦЕНТ"
#
#        org_tin  org_number  region_code   region_name region_type  \
# 0  273080245.0         NaN            2  БАШКОРТОСТАН  РЕСПУБЛИКА
# 1  276115295.0         NaN            2  БАШКОРТОСТАН  РЕСПУБЛИКА
#
#   district_name district_type city_name city_type settlement_name  \
# 0           NaN           NaN       УФА     ГОРОД             NaN
# 1           NaN           NaN       УФА     ГОРОД             NaN
#
#   settlement_type  activity_code_main  start_date    end_date  \
# 0             NaN                69.1  2017-04-10         NaN
# 1             NaN                69.1  2016-12-10  2022-03-10
#
#   region_type_norm district_type_norm city_type_norm settlement_type_norm  \
# 0       Республика                NaN          Город                  NaN
# 1       Республика                NaN          Город                  NaN
#
#   region_name_cities    region_name_with_type  region_name_settlements  \
# 0       Башкортостан  БАШКОРТОСТАН Республика  Республика Башкортостан
# 1       Башкортостан  БАШКОРТОСТАН Республика  Республика Башкортостан
#
#   region_for_join district_for_join city_for_join settlement_for_join  id_c1
# 0    БАШКОРТОСТАН               NaN           УФА                 NaN   62.0
# 1    БАШКОРТОСТАН               NaN           УФА                 NaN   62.0

# %%
merged_1["id_c1"].notna().sum() / merged_1.shape[0]
# Out:
# 0.852

# %%
cities_for_join = cities_for_join.loc[cities_for_join["settlement_for_join"].isna()]
assert cities_for_join.shape == cities_for_join.drop_duplicates().shape
cities_for_join.drop(columns="settlement_for_join", inplace=True)
cities_for_join.shape
# Out:
# (1127, 4)

# %%
merged_2 = merged_1.merge(
    cities_for_join,
    how="left",
    on=("region_for_join", "district_for_join", "city_for_join"),
)
merged_2.rename(columns={"id": "id_c2"}, inplace=True)
assert merged_2.shape[0] == rsmp_nrows
merged_2.head(2)
# Out:
#    index  kind  category  ind_tin  ind_number first_name last_name patronymic  \
# 0      0     1         1      NaN         NaN        NaN       NaN        NaN
# 1      1     1         1      NaN         NaN        NaN       NaN        NaN
#
#                                             org_name org_short_name  \
# 0  ОБЩЕСТВО С ОГРАНИЧЕННОЙ ОТВЕТСТВЕННОСТЬЮ "АВАН...  ООО "АВАНТАЖ"
# 1  ОБЩЕСТВО С ОГРАНИЧЕННОЙ ОТВЕТСТВЕННОСТЬЮ "АКЦЕНТ"   ООО "АКЦЕНТ"
#
#        org_tin  org_number  region_code   region_name region_type  \
# 0  273080245.0         NaN            2  БАШКОРТОСТАН  РЕСПУБЛИКА
# 1  276115295.0         NaN            2  БАШКОРТОСТАН  РЕСПУБЛИКА
#
#   district_name district_type city_name city_type settlement_name  \
# 0           NaN           NaN       УФА     ГОРОД             NaN
# 1           NaN           NaN       УФА     ГОРОД             NaN
#
#   settlement_type  activity_code_main  start_date    end_date  \
# 0             NaN                69.1  2017-04-10         NaN
# 1             NaN                69.1  2016-12-10  2022-03-10
#
#   region_type_norm district_type_norm city_type_norm settlement_type_norm  \
# 0       Республика                NaN          Город                  NaN
# 1       Республика                NaN          Город                  NaN
#
#   region_name_cities    region_name_with_type  region_name_settlements  \
# 0       Башкортостан  БАШКОРТОСТАН Республика  Республика Башкортостан
# 1       Башкортостан  БАШКОРТОСТАН Республика  Республика Башкортостан
#
#   region_for_join district_for_join city_for_join settlement_for_join  id_c1  \
# 0    БАШКОРТОСТАН               NaN           УФА                 NaN   62.0
# 1    БАШКОРТОСТАН               NaN           УФА                 NaN   62.0
#
#    id_c2
# 0   62.0
# 1   62.0

# %%
merged_2["id_c2"].notna().sum() / merged_2.shape[0]
# Out:
# 0.879

# %%
merged_2["id_c2"].notna().sum() / merged_2.shape[0]
# Out:
# 0.879

# %%
cities_for_join = cities.loc[(cities["area_type"] == "г") & cities["city"].isna(), ["id", "region_for_join", "district_for_join"]]
cities_for_join = cities_for_join.drop_duplicates(subset=("region_for_join", "district_for_join"))
cities_for_join.shape
# Out:
# (10, 3)

# %%
merged_3 = merged_2.merge(
    cities_for_join,
    how="left",
    on=("region_for_join", "district_for_join"),
)
merged_3.rename(columns={"id": "id_c3"}, inplace=True)
assert merged_3.shape[0] == rsmp_nrows
merged_3.head(2)
# Out:
#    index  kind  category  ind_tin  ind_number first_name last_name patronymic  \
# 0      0     1         1      NaN         NaN        NaN       NaN        NaN
# 1      1     1         1      NaN         NaN        NaN       NaN        NaN
#
#                                             org_name org_short_name  \
# 0  ОБЩЕСТВО С ОГРАНИЧЕННОЙ ОТВЕТСТВЕННОСТЬЮ "АВАН...  ООО "АВАНТАЖ"
# 1  ОБЩЕСТВО С ОГРАНИЧЕННОЙ ОТВЕТСТВЕННОСТЬЮ "АКЦЕНТ"   ООО "АКЦЕНТ"
#
#        org_tin  org_number  region_code   region_name region_type  \
# 0  273080245.0         NaN            2  БАШКОРТОСТАН  РЕСПУБЛИКА
# 1  276115295.0         NaN            2  БАШКОРТОСТАН  РЕСПУБЛИКА
#
#   district_name district_type city_name city_type settlement_name  \
# 0           NaN           NaN       УФА     ГОРОД             NaN
# 1           NaN           NaN       УФА     ГОРОД             NaN
#
#   settlement_type  activity_code_main  start_date    end_date  \
# 0             NaN                69.1  2017-04-10         NaN
# 1             NaN                69.1  2016-12-10  2022-03-10
#
#   region_type_norm district_type_norm city_type_norm settlement_type_norm  \
# 0       Республика                NaN          Город                  NaN
# 1       Республика                NaN          Город                  NaN
#
#   region_name_cities    region_name_with_type  region_name_settlements  \
# 0       Башкортостан  БАШКОРТОСТАН Республика  Республика Башкортостан
# 1       Башкортостан  БАШКОРТОСТАН Республика  Республика Башкортостан
#
#   region_for_join district_for_join city_for_join settlement_for_join  id_c1  \
# 0    БАШКОРТОСТАН               NaN           УФА                 NaN   62.0
# 1    БАШКОРТОСТАН               NaN           УФА                 NaN   62.0
#
#    id_c2  id_c3
# 0   62.0    NaN
# 1   62.0    NaN

# %%
merged_3["id_c3"].notna().sum() / merged_3.shape[0]
# Out:
# 0.007

# %%
cities_for_join.rename(columns={"district_for_join": "city_for_join"}, inplace=True)

# %%
merged_4 = merged_3.merge(
    cities_for_join,
    how="left",
    on=("region_for_join", "city_for_join"),
)
merged_4.rename(columns={"id": "id_c4"}, inplace=True)
assert merged_4.shape[0] == rsmp_nrows
merged_4.head(2)
# Out:
#    index  kind  category  ind_tin  ind_number first_name last_name patronymic  \
# 0      0     1         1      NaN         NaN        NaN       NaN        NaN
# 1      1     1         1      NaN         NaN        NaN       NaN        NaN
#
#                                             org_name org_short_name  \
# 0  ОБЩЕСТВО С ОГРАНИЧЕННОЙ ОТВЕТСТВЕННОСТЬЮ "АВАН...  ООО "АВАНТАЖ"
# 1  ОБЩЕСТВО С ОГРАНИЧЕННОЙ ОТВЕТСТВЕННОСТЬЮ "АКЦЕНТ"   ООО "АКЦЕНТ"
#
#        org_tin  org_number  region_code   region_name region_type  \
# 0  273080245.0         NaN            2  БАШКОРТОСТАН  РЕСПУБЛИКА
# 1  276115295.0         NaN            2  БАШКОРТОСТАН  РЕСПУБЛИКА
#
#   district_name district_type city_name city_type settlement_name  \
# 0           NaN           NaN       УФА     ГОРОД             NaN
# 1           NaN           NaN       УФА     ГОРОД             NaN
#
#   settlement_type  activity_code_main  start_date    end_date  \
# 0             NaN                69.1  2017-04-10         NaN
# 1             NaN                69.1  2016-12-10  2022-03-10
#
#   region_type_norm district_type_norm city_type_norm settlement_type_norm  \
# 0       Республика                NaN          Город                  NaN
# 1       Республика                NaN          Город                  NaN
#
#   region_name_cities    region_name_with_type  region_name_settlements  \
# 0       Башкортостан  БАШКОРТОСТАН Республика  Республика Башкортостан
# 1       Башкортостан  БАШКОРТОСТАН Республика  Республика Башкортостан
#
#   region_for_join district_for_join city_for_join settlement_for_join  id_c1  \
# 0    БАШКОРТОСТАН               NaN           УФА                 NaN   62.0
# 1    БАШКОРТОСТАН               NaN           УФА                 NaN   62.0
#
#    id_c2  id_c3  id_c4
# 0   62.0    NaN    NaN
# 1   62.0    NaN    NaN

# %%
merged_4["id_c4"].notna().sum() / merged_4.shape[0]
# Out:
# 0.011

# %%
cities_for_join = cities.loc[(cities["area_type"] != "г") & cities["city"].notna() & cities["settlement"].isna(), ["id", "region_for_join", "city_for_join"]]
cities_for_join.drop_duplicates(["region_for_join", "city_for_join"], keep=False, inplace=True)
cities_for_join.head(2)
# Out:
#    id region_for_join city_for_join
# 0   0          АДЫГЕЯ      АДЫГЕЙСК
# 1   1          АДЫГЕЯ        МАЙКОП

# %%
merged_4_1 = merged_4.merge(
    cities_for_join,
    how="left",
    on=("region_for_join", "city_for_join"),
)
merged_4_1.rename(columns={"id": "id_c4_1"}, inplace=True)
assert merged_4_1.shape[0] == rsmp_nrows
merged_4_1.head(2)
# Out:
#    index  kind  category  ind_tin  ind_number first_name last_name patronymic  \
# 0      0     1         1      NaN         NaN        NaN       NaN        NaN
# 1      1     1         1      NaN         NaN        NaN       NaN        NaN
#
#                                             org_name org_short_name  \
# 0  ОБЩЕСТВО С ОГРАНИЧЕННОЙ ОТВЕТСТВЕННОСТЬЮ "АВАН...  ООО "АВАНТАЖ"
# 1  ОБЩЕСТВО С ОГРАНИЧЕННОЙ ОТВЕТСТВЕННОСТЬЮ "АКЦЕНТ"   ООО "АКЦЕНТ"
#
#        org_tin  org_number  region_code   region_name region_type  \
# 0  273080245.0         NaN            2  БАШКОРТОСТАН  РЕСПУБЛИКА
# 1  276115295.0         NaN            2  БАШКОРТОСТАН  РЕСПУБЛИКА
#
#   district_name district_type city_name city_type settlement_name  \
# 0           NaN           NaN       УФА     ГОРОД             NaN
# 1           NaN           NaN       УФА     ГОРОД             NaN
#
#   settlement_type  activity_code_main  start_date    end_date  \
# 0             NaN                69.1  2017-04-10         NaN
# 1             NaN                69.1  2016-12-10  2022-03-10
#
#   region_type_norm district_type_norm city_type_norm settlement_type_norm  \
# 0       Республика                NaN          Город                  NaN
# 1       Республика                NaN          Город                  NaN
#
#   region_name_cities    region_name_with_type  region_name_settlements  \
# 0       Башкортостан  БАШКОРТОСТАН Республика  Республика Башкортостан
# 1       Башкортостан  БАШКОРТОСТАН Республика  Республика Башкортостан
#
#   region_for_join district_for_join city_for_join settlement_for_join  id_c1  \
# 0    БАШКОРТОСТАН               NaN           УФА                 NaN   62.0
# 1    БАШКОРТОСТАН               NaN           УФА                 NaN   62.0
#
#    id_c2  id_c3  id_c4  id_c4_1
# 0   62.0    NaN    NaN     62.0
# 1   62.0    NaN    NaN     62.0

# %%
merged_4 = merged_4_1

# %%
join_cols = ["region_for_join", "municipality_for_join", "settlement_for_join", "settlement_type_for_join"]
selected_cols = ["region_name_settlements", "district_name", "settlement_name", "settlement_type_norm"]
merged_4[join_cols] = merged_4[selected_cols].apply(lambda x: x.str.replace("Ё", "Е").str.upper())
assert merged_4.shape[0] == rsmp_nrows
merged_4.head(2)
# Out:
#    index  kind  category  ind_tin  ind_number first_name last_name patronymic  \
# 0      0     1         1      NaN         NaN        NaN       NaN        NaN
# 1      1     1         1      NaN         NaN        NaN       NaN        NaN
#
#                                             org_name org_short_name  \
# 0  ОБЩЕСТВО С ОГРАНИЧЕННОЙ ОТВЕТСТВЕННОСТЬЮ "АВАН...  ООО "АВАНТАЖ"
# 1  ОБЩЕСТВО С ОГРАНИЧЕННОЙ ОТВЕТСТВЕННОСТЬЮ "АКЦЕНТ"   ООО "АКЦЕНТ"
#
#        org_tin  org_number  region_code   region_name region_type  \
# 0  273080245.0         NaN            2  БАШКОРТОСТАН  РЕСПУБЛИКА
# 1  276115295.0         NaN            2  БАШКОРТОСТАН  РЕСПУБЛИКА
#
#   district_name district_type city_name city_type settlement_name  \
# 0           NaN           NaN       УФА     ГОРОД             NaN
# 1           NaN           NaN       УФА     ГОРОД             NaN
#
#   settlement_type  activity_code_main  start_date    end_date  \
# 0             NaN                69.1  2017-04-10         NaN
# 1             NaN                69.1  2016-12-10  2022-03-10
#
#   region_type_norm district_type_norm city_type_norm settlement_type_norm  \
# 0       Республика                NaN          Город                  NaN
# 1       Республика                NaN          Город                  NaN
#
#   region_name_cities    region_name_with_type  region_name_settlements  \
# 0       Башкортостан  БАШКОРТОСТАН Республика  Республика Башкортостан
# 1       Башкортостан  БАШКОРТОСТАН Республика  Республика Башкортостан
#
#            region_for_join district_for_join city_for_join  \
# 0  РЕСПУБЛИКА БАШКОРТОСТАН               NaN           УФА
# 1  РЕСПУБЛИКА БАШКОРТОСТАН               NaN           УФА
#
#   settlement_for_join  id_c1  id_c2  id_c3  id_c4  id_c4_1  \
# 0                 NaN   62.0   62.0    NaN    NaN     62.0
# 1                 NaN   62.0   62.0    NaN    NaN     62.0
#
#   municipality_for_join settlement_type_for_join
# 0                   NaN                      NaN
# 1                   NaN                      NaN

# %%
socr_abbr_to_full = socr[["name", "name_full"]].drop_duplicates("name").rename(columns={"name": "type", "name_full": "settlement_type"})
socr_abbr_to_full.head(3)
# Out:
#    type     settlement_type
# 0    АО    Автономный округ
# 1  Аобл  Автономная область
# 2     г               Город

# %%
settlements_for_join = settlements[["id", "region", "municipality", "settlement", "type"]]
settlements_for_join_with_types = settlements_for_join.merge(socr_abbr_to_full, how="left", on="type")
assert settlements_for_join_with_types.shape[0] == settlements_for_join.shape[0]
settlements_for_join_with_types.head(2)
# Out:
#    id             region municipality  settlement type settlement_type
# 0   0  Орловская область   Болховский  Колонтаева    д         Деревня
# 1   1    Республика Крым       Алушта     Пушкино    с            Село

# %%
selected_cols = ["region", "municipality", "settlement", "settlement_type"]
settlements_for_join_with_types[join_cols] = settlements_for_join_with_types[selected_cols].apply(lambda x: x.str.upper().str.replace("Ё", "Е"))
settlements_for_join_with_types.drop(columns=selected_cols + ["type"], inplace=True)
settlements_for_join_with_types.drop_duplicates(subset=join_cols, keep=False, inplace=True)
settlements_for_join_with_types.head(3)
# Out:
#    id    region_for_join  municipality_for_join settlement_for_join  \
# 0   0  ОРЛОВСКАЯ ОБЛАСТЬ             БОЛХОВСКИЙ          КОЛОНТАЕВА
# 1   1    РЕСПУБЛИКА КРЫМ                 АЛУШТА             ПУШКИНО
# 2   2   ЛИПЕЦКАЯ ОБЛАСТЬ  ЛЕВ-ТОЛСТОВСКИЙ РАЙОН            БАРЯТИНО
#
#   settlement_type_for_join
# 0                  ДЕРЕВНЯ
# 1                     СЕЛО
# 2                     СЕЛО

# %%
settlements_for_join_with_types.shape
# Out:
# (150763, 5)

# %%
merged_5 = merged_4.merge(
    settlements_for_join_with_types,
    how="left",
    on=("region_for_join", "municipality_for_join", "settlement_for_join", "settlement_type_for_join"),
)
merged_5.rename(columns={"id": "id_s1"}, inplace=True)
assert merged_5.shape[0] == rsmp_nrows
merged_5.head(2)
# Out:
#    index  kind  category  ind_tin  ind_number first_name last_name patronymic  \
# 0      0     1         1      NaN         NaN        NaN       NaN        NaN
# 1      1     1         1      NaN         NaN        NaN       NaN        NaN
#
#                                             org_name org_short_name  \
# 0  ОБЩЕСТВО С ОГРАНИЧЕННОЙ ОТВЕТСТВЕННОСТЬЮ "АВАН...  ООО "АВАНТАЖ"
# 1  ОБЩЕСТВО С ОГРАНИЧЕННОЙ ОТВЕТСТВЕННОСТЬЮ "АКЦЕНТ"   ООО "АКЦЕНТ"
#
#        org_tin  org_number  region_code   region_name region_type  \
# 0  273080245.0         NaN            2  БАШКОРТОСТАН  РЕСПУБЛИКА
# 1  276115295.0         NaN            2  БАШКОРТОСТАН  РЕСПУБЛИКА
#
#   district_name district_type city_name city_type settlement_name  \
# 0           NaN           NaN       УФА     ГОРОД             NaN
# 1           NaN           NaN       УФА     ГОРОД             NaN
#
#   settlement_type  activity_code_main  start_date    end_date  \
# 0             NaN                69.1  2017-04-10         NaN
# 1             NaN                69.1  2016-12-10  2022-03-10
#
#   region_type_norm district_type_norm city_type_norm settlement_type_norm  \
# 0       Республика                NaN          Город                  NaN
# 1       Республика                NaN          Город                  NaN
#
#   region_name_cities    region_name_with_type  region_name_settlements  \
# 0       Башкортостан  БАШКОРТОСТАН Республика  Республика Башкортостан
# 1       Башкортостан  БАШКОРТОСТАН Республика  Республика Башкортостан
#
#            region_for_join district_for_join city_for_join  \
# 0  РЕСПУБЛИКА БАШКОРТОСТАН               NaN           УФА
# 1  РЕСПУБЛИКА БАШКОРТОСТАН               NaN           УФА
#
#   settlement_for_join  id_c1  id_c2  id_c3  id_c4  id_c4_1  \
# 0                 NaN   62.0   62.0    NaN    NaN     62.0
# 1                 NaN   62.0   62.0    NaN    NaN     62.0
#
#   municipality_for_join settlement_type_for_join  id_s1
# 0                   NaN                      NaN    NaN
# 1                   NaN                      NaN    NaN

# %%
settlements_for_join = settlements_for_join_with_types.drop(columns="municipality_for_join")
settlements_for_join.drop_duplicates(subset=("region_for_join", "settlement_for_join", "settlement_type_for_join"), keep=False, inplace=True)
settlements_for_join.shape
# Out:
# (116245, 4)

# %%
merged_6 = merged_5.merge(
    settlements_for_join,
    how="left",
    on=("region_for_join", "settlement_for_join", "settlement_type_for_join"),
)
merged_6.rename(columns={"id": "id_s2"}, inplace=True)
assert merged_6.shape[0] == rsmp_nrows
merged_6.head(2)
# Out:
#    index  kind  category  ind_tin  ind_number first_name last_name patronymic  \
# 0      0     1         1      NaN         NaN        NaN       NaN        NaN
# 1      1     1         1      NaN         NaN        NaN       NaN        NaN
#
#                                             org_name org_short_name  \
# 0  ОБЩЕСТВО С ОГРАНИЧЕННОЙ ОТВЕТСТВЕННОСТЬЮ "АВАН...  ООО "АВАНТАЖ"
# 1  ОБЩЕСТВО С ОГРАНИЧЕННОЙ ОТВЕТСТВЕННОСТЬЮ "АКЦЕНТ"   ООО "АКЦЕНТ"
#
#        org_tin  org_number  region_code   region_name region_type  \
# 0  273080245.0         NaN            2  БАШКОРТОСТАН  РЕСПУБЛИКА
# 1  276115295.0         NaN            2  БАШКОРТОСТАН  РЕСПУБЛИКА
#
#   district_name district_type city_name city_type settlement_name  \
# 0           NaN           NaN       УФА     ГОРОД             NaN
# 1           NaN           NaN       УФА     ГОРОД             NaN
#
#   settlement_type  activity_code_main  start_date    end_date  \
# 0             NaN                69.1  2017-04-10         NaN
# 1             NaN                69.1  2016-12-10  2022-03-10
#
#   region_type_norm district_type_norm city_type_norm settlement_type_norm  \
# 0       Республика                NaN          Город                  NaN
# 1       Республика                NaN          Город                  NaN
#
#   region_name_cities    region_name_with_type  region_name_settlements  \
# 0       Башкортостан  БАШКОРТОСТАН Республика  Республика Башкортостан
# 1       Башкортостан  БАШКОРТОСТАН Республика  Республика Башкортостан
#
#            region_for_join district_for_join city_for_join  \
# 0  РЕСПУБЛИКА БАШКОРТОСТАН               NaN           УФА
# 1  РЕСПУБЛИКА БАШКОРТОСТАН               NaN           УФА
#
#   settlement_for_join  id_c1  id_c2  id_c3  id_c4  id_c4_1  \
# 0                 NaN   62.0   62.0    NaN    NaN     62.0
# 1                 NaN   62.0   62.0    NaN    NaN     62.0
#
#   municipality_for_join settlement_type_for_join  id_s1  id_s2
# 0                   NaN                      NaN    NaN    NaN
# 1                   NaN                      NaN    NaN    NaN

# %%
settlements_for_join = settlements_for_join.drop(columns="settlement_type_for_join")
settlements_for_join.drop_duplicates(subset=("region_for_join", "settlement_for_join"), keep=False, inplace=True)
settlements_for_join.shape
# Out:
# (109739, 3)

# %%
merged_7 = merged_6.merge(
    settlements_for_join,
    how="left",
    on=("region_for_join", "settlement_for_join"),
)
merged_7.rename(columns={"id": "id_s3"}, inplace=True)
assert merged_7.shape[0] == rsmp_nrows
merged_7.head(2)
# Out:
#    index  kind  category  ind_tin  ind_number first_name last_name patronymic  \
# 0      0     1         1      NaN         NaN        NaN       NaN        NaN
# 1      1     1         1      NaN         NaN        NaN       NaN        NaN
#
#                                             org_name org_short_name  \
# 0  ОБЩЕСТВО С ОГРАНИЧЕННОЙ ОТВЕТСТВЕННОСТЬЮ "АВАН...  ООО "АВАНТАЖ"
# 1  ОБЩЕСТВО С ОГРАНИЧЕННОЙ ОТВЕТСТВЕННОСТЬЮ "АКЦЕНТ"   ООО "АКЦЕНТ"
#
#        org_tin  org_number  region_code   region_name region_type  \
# 0  273080245.0         NaN            2  БАШКОРТОСТАН  РЕСПУБЛИКА
# 1  276115295.0         NaN            2  БАШКОРТОСТАН  РЕСПУБЛИКА
#
#   district_name district_type city_name city_type settlement_name  \
# 0           NaN           NaN       УФА     ГОРОД             NaN
# 1           NaN           NaN       УФА     ГОРОД             NaN
#
#   settlement_type  activity_code_main  start_date    end_date  \
# 0             NaN                69.1  2017-04-10         NaN
# 1             NaN                69.1  2016-12-10  2022-03-10
#
#   region_type_norm district_type_norm city_type_norm settlement_type_norm  \
# 0       Республика                NaN          Город                  NaN
# 1       Республика                NaN          Город                  NaN
#
#   region_name_cities    region_name_with_type  region_name_settlements  \
# 0       Башкортостан  БАШКОРТОСТАН Республика  Республика Башкортостан
# 1       Башкортостан  БАШКОРТОСТАН Республика  Республика Башкортостан
#
#            region_for_join district_for_join city_for_join  \
# 0  РЕСПУБЛИКА БАШКОРТОСТАН               NaN           УФА
# 1  РЕСПУБЛИКА БАШКОРТОСТАН               NaN           УФА
#
#   settlement_for_join  id_c1  id_c2  id_c3  id_c4  id_c4_1  \
# 0                 NaN   62.0   62.0    NaN    NaN     62.0
# 1                 NaN   62.0   62.0    NaN    NaN     62.0
#
#   municipality_for_join settlement_type_for_join  id_s1  id_s2  id_s3
# 0                   NaN                      NaN    NaN    NaN    NaN
# 1                   NaN                      NaN    NaN    NaN    NaN

# %%
merged_7["municipality_for_join"] = merged_7["district_name"] + " " + merged_7["district_type_norm"].str.upper()
merged_7.head(2)
# Out:
#    index  kind  category  ind_tin  ind_number first_name last_name patronymic  \
# 0      0     1         1      NaN         NaN        NaN       NaN        NaN
# 1      1     1         1      NaN         NaN        NaN       NaN        NaN
#
#                                             org_name org_short_name  \
# 0  ОБЩЕСТВО С ОГРАНИЧЕННОЙ ОТВЕТСТВЕННОСТЬЮ "АВАН...  ООО "АВАНТАЖ"
# 1  ОБЩЕСТВО С ОГРАНИЧЕННОЙ ОТВЕТСТВЕННОСТЬЮ "АКЦЕНТ"   ООО "АКЦЕНТ"
#
#        org_tin  org_number  region_code   region_name region_type  \
# 0  273080245.0         NaN            2  БАШКОРТОСТАН  РЕСПУБЛИКА
# 1  276115295.0         NaN            2  БАШКОРТОСТАН  РЕСПУБЛИКА
#
#   district_name district_type city_name city_type settlement_name  \
# 0           NaN           NaN       УФА     ГОРОД             NaN
# 1           NaN           NaN       УФА     ГОРОД             NaN
#
#   settlement_type  activity_code_main  start_date    end_date  \
# 0             NaN                69.1  2017-04-10         NaN
# 1             NaN                69.1  2016-12-10  2022-03-10
#
#   region_type_norm district_type_norm city_type_norm settlement_type_norm  \
# 0       Республика                NaN          Город                  NaN
# 1       Республика                NaN          Город                  NaN
#
#   region_name_cities    region_name_with_type  region_name_settlements  \
# 0       Башкортостан  БАШКОРТОСТАН Республика  Республика Башкортостан
# 1       Башкортостан  БАШКОРТОСТАН Республика  Республика Башкортостан
#
#            region_for_join district_for_join city_for_join  \
# 0  РЕСПУБЛИКА БАШКОРТОСТАН               NaN           УФА
# 1  РЕСПУБЛИКА БАШКОРТОСТАН               NaN           УФА
#
#   settlement_for_join  id_c1  id_c2  id_c3  id_c4  id_c4_1  \
# 0                 NaN   62.0   62.0    NaN    NaN     62.0
# 1                 NaN   62.0   62.0    NaN    NaN     62.0
#
#   municipality_for_join settlement_type_for_join  id_s1  id_s2  id_s3
# 0                   NaN                      NaN    NaN    NaN    NaN
# 1                   NaN                      NaN    NaN    NaN    NaN

# %%
settlements_for_join = settlements_for_join_with_types.drop(columns=("settlement_type_for_join"))
settlements_for_join.drop_duplicates(subset=("region_for_join", "municipality_for_join", "settlement_for_join"), keep=False, inplace=True)
settlements_for_join.head(2)
# Out:
#    id    region_for_join municipality_for_join settlement_for_join
# 0   0  ОРЛОВСКАЯ ОБЛАСТЬ            БОЛХОВСКИЙ          КОЛОНТАЕВА
# 1   1    РЕСПУБЛИКА КРЫМ                АЛУШТА             ПУШКИНО

# %%
merged_8 = merged_7.merge(
    settlements_for_join,
    how="left",
    on=("region_for_join",  "municipality_for_join", "settlement_for_join"),
)
merged_8.rename(columns={"id": "id_s4"}, inplace=True)
assert merged_8.shape[0] == rsmp_nrows
merged_8.head(2)
# Out:
#    index  kind  category  ind_tin  ind_number first_name last_name patronymic  \
# 0      0     1         1      NaN         NaN        NaN       NaN        NaN
# 1      1     1         1      NaN         NaN        NaN       NaN        NaN
#
#                                             org_name org_short_name  \
# 0  ОБЩЕСТВО С ОГРАНИЧЕННОЙ ОТВЕТСТВЕННОСТЬЮ "АВАН...  ООО "АВАНТАЖ"
# 1  ОБЩЕСТВО С ОГРАНИЧЕННОЙ ОТВЕТСТВЕННОСТЬЮ "АКЦЕНТ"   ООО "АКЦЕНТ"
#
#        org_tin  org_number  region_code   region_name region_type  \
# 0  273080245.0         NaN            2  БАШКОРТОСТАН  РЕСПУБЛИКА
# 1  276115295.0         NaN            2  БАШКОРТОСТАН  РЕСПУБЛИКА
#
#   district_name district_type city_name city_type settlement_name  \
# 0           NaN           NaN       УФА     ГОРОД             NaN
# 1           NaN           NaN       УФА     ГОРОД             NaN
#
#   settlement_type  activity_code_main  start_date    end_date  \
# 0             NaN                69.1  2017-04-10         NaN
# 1             NaN                69.1  2016-12-10  2022-03-10
#
#   region_type_norm district_type_norm city_type_norm settlement_type_norm  \
# 0       Республика                NaN          Город                  NaN
# 1       Республика                NaN          Город                  NaN
#
#   region_name_cities    region_name_with_type  region_name_settlements  \
# 0       Башкортостан  БАШКОРТОСТАН Республика  Республика Башкортостан
# 1       Башкортостан  БАШКОРТОСТАН Республика  Республика Башкортостан
#
#            region_for_join district_for_join city_for_join  \
# 0  РЕСПУБЛИКА БАШКОРТОСТАН               NaN           УФА
# 1  РЕСПУБЛИКА БАШКОРТОСТАН               NaN           УФА
#
#   settlement_for_join  id_c1  id_c2  id_c3  id_c4  id_c4_1  \
# 0                 NaN   62.0   62.0    NaN    NaN     62.0
# 1                 NaN   62.0   62.0    NaN    NaN     62.0
#
#   municipality_for_join settlement_type_for_join  id_s1  id_s2  id_s3  id_s4
# 0                   NaN                      NaN    NaN    NaN    NaN    NaN
# 1                   NaN                      NaN    NaN    NaN    NaN    NaN

# %%
merged_8.notna().sum()
# Out:
# index                       172095
# kind                        172095
# category                    172095
# ind_tin                      92966
# ind_number                   16877
# first_name                   92965
# last_name                    92966
# patronymic                   92511
# org_name                     79129
# org_short_name               78924
# org_tin                      79129
# org_number                    9939
# region_code                 172095
# region_name                 172075
# region_type                 172075
# district_name                28110
# district_type                28110
# city_name                   114816
# city_type                   114816
# settlement_name              20697
# settlement_type              20697
# activity_code_main          172095
# start_date                  172095
# end_date                     31906
# region_type_norm            172075
# district_type_norm           28110
# city_type_norm              114816
# settlement_type_norm         20692
# region_name_cities          172075
# region_name_with_type       172075
# region_name_settlements     172075
# region_for_join             172075
# district_for_join            28110
# city_for_join               114816
# settlement_for_join          20697
# id_c1                       146594
# id_c2                       151287
# id_c3                         1238
# id_c4                         1895
# id_c4_1                     111880
# municipality_for_join        28110
# settlement_type_for_join     20692
# id_s1                         3206
# id_s2                        12494
# id_s3                        15052
# id_s4                         8873
# dtype: int64

# %%
merged = merged_8.drop(columns=[c for c in merged_8.columns if "_for_join" in c])
merged.head(2)
# Out:
#    index  kind  category  ind_tin  ind_number first_name last_name patronymic  \
# 0      0     1         1      NaN         NaN        NaN       NaN        NaN
# 1      1     1         1      NaN         NaN        NaN       NaN        NaN
#
#                                             org_name org_short_name  \
# 0  ОБЩЕСТВО С ОГРАНИЧЕННОЙ ОТВЕТСТВЕННОСТЬЮ "АВАН...  ООО "АВАНТАЖ"
# 1  ОБЩЕСТВО С ОГРАНИЧЕННОЙ ОТВЕТСТВЕННОСТЬЮ "АКЦЕНТ"   ООО "АКЦЕНТ"
#
#        org_tin  org_number  region_code   region_name region_type  \
# 0  273080245.0         NaN            2  БАШКОРТОСТАН  РЕСПУБЛИКА
# 1  276115295.0         NaN            2  БАШКОРТОСТАН  РЕСПУБЛИКА
#
#   district_name district_type city_name city_type settlement_name  \
# 0           NaN           NaN       УФА     ГОРОД             NaN
# 1           NaN           NaN       УФА     ГОРОД             NaN
#
#   settlement_type  activity_code_main  start_date    end_date  \
# 0             NaN                69.1  2017-04-10         NaN
# 1             NaN                69.1  2016-12-10  2022-03-10
#
#   region_type_norm district_type_norm city_type_norm settlement_type_norm  \
# 0       Республика                NaN          Город                  NaN
# 1       Республика                NaN          Город                  NaN
#
#   region_name_cities    region_name_with_type  region_name_settlements  id_c1  \
# 0       Башкортостан  БАШКОРТОСТАН Республика  Республика Башкортостан   62.0
# 1       Башкортостан  БАШКОРТОСТАН Республика  Республика Башкортостан   62.0
#
#    id_c2  id_c3  id_c4  id_c4_1  id_s1  id_s2  id_s3  id_s4
# 0   62.0    NaN    NaN     62.0    NaN    NaN    NaN    NaN
# 1   62.0    NaN    NaN     62.0    NaN    NaN    NaN    NaN

# %%
merged[[c for c in merged.columns if "id_" in c]].notna().sum(axis=1).value_counts()
# Out:
# 3    117172
# 2     44157
# 1      6187
# 0      2958
# 4      1603
# 5        18
# Name: count, dtype: int64

# %%
merged[[c for c in merged.columns if "id_" in c]].apply(lambda x: len(x.dropna().unique()), axis=1).value_counts()
# Out:
# 1    165502
# 2      3618
# 0      2958
# 3        17
# Name: count, dtype: int64

# %%
2958 / rsmp_nrows
# Out:
# 0.017

# %%
def get_geo_id(row):
    for option in ("s1", "s2", "s3", "s4", "c1", "c2", "c4_1", "c3", "c4"):
        val = row[f"id_{option}"]
        if pd.isna(val):
            continue
        if option.startswith("c"):
            return pd.Series(dict(city_id=val, settlement_id=np.nan))
        else:
            return pd.Series(dict(city_id=np.nan, settlement_id=val))

# %%
merged.loc[:, ["city_id", "settlement_id"]] = merged.apply(get_geo_id, axis=1)

# %%
merged.notna().sum()
# Out:
# index                      172095
# kind                       172095
# category                   172095
# ind_tin                     92966
# ind_number                  16877
# first_name                  92965
# last_name                   92966
# patronymic                  92511
# org_name                    79129
# org_short_name              78924
# org_tin                     79129
# org_number                   9939
# region_code                172095
# region_name                172075
# region_type                172075
# district_name               28110
# district_type               28110
# city_name                  114816
# city_type                  114816
# settlement_name             20697
# settlement_type             20697
# activity_code_main         172095
# start_date                 172095
# end_date                    31906
# region_type_norm           172075
# district_type_norm          28110
# city_type_norm             114816
# settlement_type_norm        20692
# region_name_cities         172075
# region_name_with_type      172075
# region_name_settlements    172075
# id_c1                      146594
# id_c2                      151287
# id_c3                        1238
# id_c4                        1895
# id_c4_1                    111880
# id_s1                        3206
# id_s2                       12494
# id_s3                       15052
# id_s4                        8873
# city_id                    151610
# settlement_id               17527
# dtype: int64

# %%
merged.loc[merged["city_name"].notna() & merged["city_id"].isna()]
# Out:
#          index  kind  category       ind_tin    ind_number first_name  \
# 86          86     1         1           NaN           NaN        NaN
# 149        149     1         1           NaN           NaN        NaN
# 375        375     1         1           NaN           NaN        NaN
# 531        531     2         1  3.459193e+11  3.229401e+14      ОЛЬГА
# 532        532     2         1  3.459193e+11  3.229401e+14      ОЛЬГА
# ...        ...   ...       ...           ...           ...        ...
# 171834  171834     2         1  5.012150e+11           NaN     АНДРЕЙ
# 171853  171853     2         1  5.079012e+11           NaN      ДЕНИС
# 171859  171859     2         1  5.225557e+11           NaN  ЕКАТЕРИНА
# 172046  172046     2         1  7.727930e+11           NaN    НАТАЛЬЯ
# 172048  172048     2         1  7.728111e+11           NaN      СЕМЕН
#
#          last_name     patronymic  \
# 86             NaN            NaN
# 149            NaN            NaN
# 375            NaN            NaN
# 531      МЕДВЕДЕВА   ВЛАДИМИРОВНА
# 532      МЕДВЕДЕВА   ВЛАДИМИРОВНА
# ...            ...            ...
# 171834   ФЕДОРЕНКО    АЛЬБЕРТОВИЧ
# 171853      КУНАЕВ      СЕРГЕЕВИЧ
# 171859     БЕШЛЯГА  АЛЕКСАНДРОВНА
# 172046  ЦЫБРЕНКОВА       ПЕТРОВНА
# 172048       ДОРОШ     НИКОЛАЕВИЧ
#
#                                                  org_name  \
# 86      ОБЩЕСТВО С ОГРАНИЧЕННОЙ ОТВЕТСТВЕННОСТЬЮ "АЛЬЯ...
# 149     ОБЩЕСТВО С ОГРАНИЧЕННОЙ ОТВЕТСТВЕННОСТЬЮ "ЮРИД...
# 375     ОБЩЕСТВО С ОГРАНИЧЕННОЙ ОТВЕТСТВЕННОСТЬЮ "ЦЕНТ...
# 531                                                   NaN
# 532                                                   NaN
# ...                                                   ...
# 171834                                                NaN
# 171853                                                NaN
# 171859                                                NaN
# 172046                                                NaN
# 172048                                                NaN
#
#                  org_short_name       org_tin  org_number  region_code  \
# 86      ООО "АЛЬЯНСПРОФКОНСАЛТ"  2.627027e+09         NaN           26
# 149            ООО "ЮФ "АКЦЕПТ"  5.024199e+09         NaN           50
# 375            ООО "ТВОЁ ПРАВО"  9.105020e+09         NaN           91
# 531                         NaN           NaN         NaN           94
# 532                         NaN           NaN         NaN           94
# ...                         ...           ...         ...          ...
# 171834                      NaN           NaN         NaN           50
# 171853                      NaN           NaN         NaN           50
# 171859                      NaN           NaN         NaN           52
# 172046                      NaN           NaN         NaN           50
# 172048                      NaN           NaN         NaN           50
#
#                region_name region_type   district_name district_type  \
# 86          СТАВРОПОЛЬСКИЙ        КРАЙ             NaN           NaN
# 149             МОСКОВСКАЯ     ОБЛАСТЬ             NaN           NaN
# 375                   КРЫМ       РЕСП.             NaN           NaN
# 531     ЛУГАНСКАЯ НАРОДНАЯ       РЕСП.             NaN           NaN
# 532     ЛУГАНСКАЯ НАРОДНАЯ       РЕСП.     ЛУТУГИНСКИЙ           Р-Н
# ...                    ...         ...             ...           ...
# 171834          МОСКОВСКАЯ     ОБЛАСТЬ             NaN           NaN
# 171853          МОСКОВСКАЯ     ОБЛАСТЬ             NaN           NaN
# 171859       НИЖЕГОРОДСКАЯ     ОБЛАСТЬ             NaN           NaN
# 172046          МОСКОВСКАЯ     ОБЛАСТЬ  НАРО-ФОМИНСКИЙ         РАЙОН
# 172048          МОСКОВСКАЯ     ОБЛАСТЬ             NaN           NaN
#
#            city_name        city_type  settlement_name settlement_type  \
# 86      ЖЕЛЕЗНОВОДСК            ГОРОД       ИНОЗЕМЦЕВО         ПОСЕЛОК
# 149      КРАСНОГОРСК            ГОРОД        ПУТИЛКОВО         ДЕРЕВНЯ
# 375             ЯЛТА               Г.           СИМЕИЗ            ПГТ.
# 531         ЛУТУГИНО               Г.              NaN             NaN
# 532         ЛУТУГИНО               Г.              NaN             NaN
# ...              ...              ...              ...             ...
# 171834      БАЛАШИХА            ГОРОД  ЖЕЛЕЗНОДОРОЖНЫЙ      МИКРОРАЙОН
# 171853     ШАХОВСКАЯ  РАБОЧИЙ ПОСЕЛОК              NaN             NaN
# 171859     ДЗЕРЖИНСК            ГОРОД             ПЫРА         ПОСЕЛОК
# 172046     АПРЕЛЕВКА            ГОРОД              NaN             NaN
# 172048         ОЗЕРЫ            ГОРОД         КОМАРЕВО            СЕЛО
#
#         activity_code_main  start_date    end_date region_type_norm  \
# 86                    69.1  2020-02-10         NaN             Край
# 149                   69.1  2019-10-10         NaN          Область
# 375                   69.1  2021-06-10         NaN       Республика
# 531                   69.1  2023-01-10  2023-02-10       Республика
# 532                   69.1  2023-02-10         NaN       Республика
# ...                    ...         ...         ...              ...
# 171834                69.1  2016-11-10  2018-06-10          Область
# 171853                69.1  2017-05-10  2020-03-10          Область
# 171859                69.1  2019-06-10         NaN          Область
# 172046                69.1  2016-08-10         NaN          Область
# 172048                69.1  2017-11-10         NaN          Область
#
#        district_type_norm   city_type_norm     settlement_type_norm  \
# 86                    NaN            Город                  Поселок
# 149                   NaN            Город                  Деревня
# 375                   NaN            Город  Поселок городского типа
# 531                   NaN            Город                      NaN
# 532                 Район            Город                      NaN
# ...                   ...              ...                      ...
# 171834                NaN            Город               Микрорайон
# 171853                NaN  Рабочий поселок                      NaN
# 171859                NaN            Город                  Поселок
# 172046              Район            Город                      NaN
# 172048                NaN            Город                     Село
#
#        region_name_cities          region_name_with_type  \
# 86         Ставропольский            СТАВРОПОЛЬСКИЙ Край
# 149            Московская             МОСКОВСКАЯ Область
# 375                  Крым                КРЫМ Республика
# 531            Курганская  ЛУГАНСКАЯ НАРОДНАЯ Республика
# 532            Курганская  ЛУГАНСКАЯ НАРОДНАЯ Республика
# ...                   ...                            ...
# 171834         Московская             МОСКОВСКАЯ Область
# 171853         Московская             МОСКОВСКАЯ Область
# 171859      Нижегородская          НИЖЕГОРОДСКАЯ Область
# 172046         Московская             МОСКОВСКАЯ Область
# 172048         Московская             МОСКОВСКАЯ Область
#
#        region_name_settlements  id_c1  id_c2  id_c3  id_c4  id_c4_1  id_s1  \
# 86         Ставропольский край    NaN  892.0    NaN    NaN    892.0    NaN
# 149         Московская область    NaN  539.0    NaN    NaN    539.0    NaN
# 375            Республика Крым    NaN  435.0    NaN    NaN    435.0    NaN
# 531            Республика Крым    NaN    NaN    NaN    NaN      NaN    NaN
# 532            Республика Крым    NaN    NaN    NaN    NaN      NaN    NaN
# ...                        ...    ...    ...    ...    ...      ...    ...
# 171834      Московская область    NaN  511.0    NaN    NaN    511.0    NaN
# 171853      Московская область    NaN    NaN    NaN    NaN      NaN    NaN
# 171859   Нижегородская область    NaN  611.0    NaN    NaN    611.0    NaN
# 172046      Московская область    NaN    NaN    NaN    NaN      NaN    NaN
# 172048      Московская область    NaN  555.0    NaN    NaN    555.0    NaN
#
#            id_s2     id_s3  id_s4  city_id  settlement_id
# 86           NaN  133452.0    NaN      NaN       133452.0
# 149     103159.0  103159.0    NaN      NaN       103159.0
# 375      99266.0   99266.0    NaN      NaN        99266.0
# 531          NaN       NaN    NaN      NaN            NaN
# 532          NaN       NaN    NaN      NaN            NaN
# ...          ...       ...    ...      ...            ...
# 171834       NaN    9237.0    NaN      NaN         9237.0
# 171853       NaN       NaN    NaN      NaN            NaN
# 171859       NaN   93319.0    NaN      NaN        93319.0
# 172046       NaN       NaN    NaN      NaN            NaN
# 172048  135665.0  135665.0    NaN      NaN       135665.0
#
# [3902 rows x 42 columns]

# %%
merged.loc[~merged["region_name"].isin(("ДОНЕЦКАЯ НАРОДНАЯ", "ЛУГАНСКАЯ НАРОДНАЯ", "ХЕРСОНСКАЯ", "ЗАПОРОЖСКАЯ"))].notna().sum()
# Out:
# index                      171921
# kind                       171921
# category                   171921
# ind_tin                     92806
# ind_number                  16717
# first_name                  92805
# last_name                   92806
# patronymic                  92351
# org_name                    79115
# org_short_name              78910
# org_tin                     79115
# org_number                   9925
# region_code                171921
# region_name                171901
# region_type                171901
# district_name               27985
# district_type               27985
# city_name                  114753
# city_type                  114753
# settlement_name             20687
# settlement_type             20687
# activity_code_main         171921
# start_date                 171921
# end_date                    31901
# region_type_norm           171901
# district_type_norm          27985
# city_type_norm             114753
# settlement_type_norm        20682
# region_name_cities         171901
# region_name_with_type      171901
# region_name_settlements    171901
# id_c1                      146594
# id_c2                      151287
# id_c3                        1238
# id_c4                        1895
# id_c4_1                    111880
# id_s1                        3206
# id_s2                       12494
# id_s3                       15051
# id_s4                        8873
# city_id                    151610
# settlement_id               17526
# dtype: int64

# %%
(151610+17526)/rsmp_nrows
# Out:
# 0.983

# %%
def remove_type_from_region_name(region_name):
    types = ["область", "Республика", "республика", "край", "автономный округ", "автономная область"]
    for t in types:
        region_name = region_name.replace(t, "")
        
    return region_name.strip()

remove_type_from_region_name("Республика Крым")
# Out:
# 'Крым'

# %%
reg_to_reg_settl = pd.DataFrame.from_records(
    [
        (x, process.extractOne(x, settlements["region"].unique(), scorer=fuzz.token_set_ratio)[0].upper())
        for x in (merged_1["region_name"] + " " + merged_1["name_full"]).dropna().unique()
    ]
)

# %%
reg_to_reg_settl
# Out:
#                                     0  \
# 0             БАШКОРТОСТАН РЕСПУБЛИКА
# 1                  БУРЯТИЯ РЕСПУБЛИКА
# 2                 ДАГЕСТАН РЕСПУБЛИКА
# 3                  КАРЕЛИЯ РЕСПУБЛИКА
# 4                 МАРИЙ ЭЛ РЕСПУБЛИКА
# ..                                ...
# 88                 ХЕРСОНСКАЯ ОБЛАСТЬ
# 89         ЧУКОТСКИЙ АВТОНОМНЫЙ ОКРУГ
# 90  ХАНТЫ-МАНСИЙСКИЙ АВТОНОМНЫЙ ОКРУГ
# 91   ТАТАРСТАН (ТАТАРСТАН) РЕСПУБЛИКА
# 92                ЗАПОРОЖСКАЯ ОБЛАСТЬ
#
#                                            1
# 0                    РЕСПУБЛИКА БАШКОРТОСТАН
# 1                         РЕСПУБЛИКА БУРЯТИЯ
# 2                        РЕСПУБЛИКА ДАГЕСТАН
# 3                         РЕСПУБЛИКА КАРЕЛИЯ
# 4                        РЕСПУБЛИКА МАРИЙ ЭЛ
# ..                                       ...
# 88                        РОСТОВСКАЯ ОБЛАСТЬ
# 89                ЧУКОТСКИЙ АВТОНОМНЫЙ ОКРУГ
# 90  ХАНТЫ-МАНСИЙСКИЙ АВТОНОМНЫЙ ОКРУГ - ЮГРА
# 91                      РЕСПУБЛИКА ТАТАРСТАН
# 92                       ВОРОНЕЖСКАЯ ОБЛАСТЬ
#
# [93 rows x 2 columns]

# %%
reg_to_reg_settl.columns = ("region_orig", "region_for_join")
merged_1["region_orig"] = merged_1["region_name"] + " " + merged_1["name_full"]
merged_1 = merged_1.merge(reg_to_reg_settl, how="left", on="region_orig")

# %%
merged_1.head(3)
# Out:
#    kind  category  ind_tin  ind_number first_name last_name patronymic  \
# 0     1         1      NaN         NaN        NaN       NaN        NaN
# 1     1         1      NaN         NaN        NaN       NaN        NaN
# 2     1         1      NaN         NaN        NaN       NaN        NaN
#
#                                             org_name org_short_name  \
# 0  ОБЩЕСТВО С ОГРАНИЧЕННОЙ ОТВЕТСТВЕННОСТЬЮ "АВАН...  ООО "АВАНТАЖ"
# 1  ОБЩЕСТВО С ОГРАНИЧЕННОЙ ОТВЕТСТВЕННОСТЬЮ "АКЦЕНТ"   ООО "АКЦЕНТ"
# 2  ОБЩЕСТВО С ОГРАНИЧЕННОЙ ОТВЕТСТВЕННОСТЬЮ "АКЦЕНТ"   ООО "АКЦЕНТ"
#
#        org_tin    org_number  region_code   region_name region_type  \
# 0  273080245.0           NaN            2  БАШКОРТОСТАН  РЕСПУБЛИКА
# 1  276115295.0           NaN            2  БАШКОРТОСТАН  РЕСПУБЛИКА
# 2  276115295.0  1.080276e+12            2  БАШКОРТОСТАН       РЕСП.
#
#   district_name district_type city_name city_type settlement_name  \
# 0           NaN           NaN       УФА     ГОРОД             NaN
# 1           NaN           NaN       УФА     ГОРОД             NaN
# 2           NaN           NaN       УФА        Г.             NaN
#
#   settlement_type  activity_code_main  start_date    end_date  \
# 0             NaN                69.1  2017-04-10         NaN
# 1             NaN                69.1  2016-12-10  2022-03-10
# 2             NaN                69.1  2022-03-10         NaN
#
#   region_for_join_x district_for_join city_for_join settlement_for_join  \
# 0      БАШКОРТОСТАН               NaN           УФА                 NaN
# 1      БАШКОРТОСТАН               NaN           УФА                 NaN
# 2      БАШКОРТОСТАН               NaN           УФА                 NaN
#
#   address  postal_code country federal_district region_type_cities  \
# 0   г Уфа     450000.0  Россия      Приволжский               Респ
# 1   г Уфа     450000.0  Россия      Приволжский               Респ
# 2   г Уфа     450000.0  Россия      Приволжский               Респ
#
#          region area_type area city_type_cities city settlement_type_cities  \
# 0  Башкортостан       NaN  NaN                г  Уфа                    NaN
# 1  Башкортостан       NaN  NaN                г  Уфа                    NaN
# 2  Башкортостан       NaN  NaN                г  Уфа                    NaN
#
#   settlement      kladr_id                               fias_id  fias_level  \
# 0        NaN  2.000001e+11  7339e834-2cb4-4734-a4c7-1fca2c66e562         4.0
# 1        NaN  2.000001e+11  7339e834-2cb4-4734-a4c7-1fca2c66e562         4.0
# 2        NaN  2.000001e+11  7339e834-2cb4-4734-a4c7-1fca2c66e562         4.0
#
#    capital_marker         okato         oktmo  tax_office timezone    geo_lat  \
# 0             2.0  8.040100e+10  8.070100e+10       200.0    UTC+5  54.734944
# 1             2.0  8.040100e+10  8.070100e+10       200.0    UTC+5  54.734944
# 2             2.0  8.040100e+10  8.070100e+10       200.0    UTC+5  54.734944
#
#      geo_lon  population  foundation_year        name   name_full  \
# 0  55.957847   1062300.0           1574.0  РЕСПУБЛИКА  РЕСПУБЛИКА
# 1  55.957847   1062300.0           1574.0  РЕСПУБЛИКА  РЕСПУБЛИКА
# 2  55.957847   1062300.0           1574.0       РЕСП.  РЕСПУБЛИКА
#
#                region_orig        region_for_join_y
# 0  БАШКОРТОСТАН РЕСПУБЛИКА  РЕСПУБЛИКА БАШКОРТОСТАН
# 1  БАШКОРТОСТАН РЕСПУБЛИКА  РЕСПУБЛИКА БАШКОРТОСТАН
# 2  БАШКОРТОСТАН РЕСПУБЛИКА  РЕСПУБЛИКА БАШКОРТОСТАН

# %%
merged_1["region_for_join"] = merged_1["region_for_join_y"]

# %%
#settlements["region_for_join"] = settlements["region"].apply(remove_type_from_region_name).str.upper()
settlements["region_for_join"] = settlements["region"].apply(lambda x: x.upper())

settlements["settlement_for_join"] = settlements["settlement"].str.upper()
settlements = settlements.loc[~settlements.duplicated(subset=["region_for_join", "settlement_for_join"], keep=False)]
settlements
# Out:
#             id                 region                municipality  \
# 0            0      Орловская область                  Болховский
# 3            3       Тверская область         Селижаровский район
# 4            4        Томская область          Парабельский район
# 5            5       Республика Алтай           Шебалинский район
# 6            6  Нижегородская область         Воскресенский район
# ...        ...                    ...                         ...
# 155915  155915      Тюменская область            Тобольский район
# 155916  155916    Ульяновская область           Вешкаймский район
# 155917  155917      Псковская область            Палкинский район
# 155919  155919       Тульская область  рабочий пос. Новогуровский
# 155920  155920     Краснодарский край          Город-курорт Анапа
#
#            settlement   type  population  children latitude_dms longitude_dms  \
# 0          Колонтаева      д           0         0     53.22.07     035.54.36
# 3              Хилово      д           2         0     56.54.20     033.25.09
# 4           Басмасово      д           6         0     58.38.12     082.02.40
# 5               Каспа      с         375       118     51.06.57     086.00.46
# 6             Апариха      д           0         0     56.53.40     045.19.08
# ...               ...    ...         ...       ...          ...           ...
# 155915       Подъемка      с          21         0     57.58.44     067.58.38
# 155916       Ребровка      д           0         0     53.59.12     046.48.35
# 155917        Шадрица      д           1         0     57.29.03     028.08.48
# 155919  Новогуровский     рп        3398       305     54.28.03     037.20.19
# 155920  Гостагаевская  ст-ца       12566      2980     45.01.21     037.30.15
#
#         latitude_dd  longitude_dd         oktmo  dadata  rosstat  \
# 0         53.368611     35.910000  5.460442e+10       0        1
# 3         56.905556     33.419167  2.865043e+10       0        1
# 4         58.636667     82.044444  6.964444e+10       0        1
# 5         51.115833     86.012778  8.465046e+10       0        1
# 6         56.894444     45.318889  2.262240e+10       0        1
# ...             ...           ...           ...     ...      ...
# 155915    57.978889     67.977222  7.164244e+10       0        1
# 155916    53.986667     46.809722  7.360744e+10       0        1
# 155917    57.484167     28.146667  5.863742e+10       0        1
# 155919    54.467500     37.338611  7.070200e+10       1        0
# 155920    45.022500     37.504167  3.703000e+09       1        0
#
#               region_for_join settlement_for_join
# 0           ОРЛОВСКАЯ ОБЛАСТЬ          КОЛОНТАЕВА
# 3            ТВЕРСКАЯ ОБЛАСТЬ              ХИЛОВО
# 4             ТОМСКАЯ ОБЛАСТЬ           БАСМАСОВО
# 5            РЕСПУБЛИКА АЛТАЙ               КАСПА
# 6       НИЖЕГОРОДСКАЯ ОБЛАСТЬ             АПАРИХА
# ...                       ...                 ...
# 155915      ТЮМЕНСКАЯ ОБЛАСТЬ            ПОДЪЕМКА
# 155916    УЛЬЯНОВСКАЯ ОБЛАСТЬ            РЕБРОВКА
# 155917      ПСКОВСКАЯ ОБЛАСТЬ             ШАДРИЦА
# 155919       ТУЛЬСКАЯ ОБЛАСТЬ       НОВОГУРОВСКИЙ
# 155920     КРАСНОДАРСКИЙ КРАЙ       ГОСТАГАЕВСКАЯ
#
# [107992 rows x 16 columns]

# %%
merged_2 = merged_1.merge(
    settlements,
    how="left",
    on=["region_for_join", "settlement_for_join"],
    suffixes=("", "_settlements")
)
merged_2.shape
# Out:
# (172095, 70)

# %%
merged_2.columns
# Out:
# Index(['kind', 'category', 'ind_tin', 'ind_number', 'first_name', 'last_name',
#        'patronymic', 'org_name', 'org_short_name', 'org_tin', 'org_number',
#        'region_code', 'region_name', 'region_type', 'district_name',
#        'district_type', 'city_name', 'city_type', 'settlement_name',
#        'settlement_type', 'activity_code_main', 'start_date', 'end_date',
#        'region_for_join_x', 'district_for_join', 'city_for_join',
#        'settlement_for_join', 'address', 'postal_code', 'country',
#        'federal_district', 'region_type_cities', 'region', 'area_type', 'area',
#        'city_type_cities', 'city', 'settlement_type_cities', 'settlement',
#        'kladr_id', 'fias_id', 'fias_level', 'capital_marker', 'okato', 'oktmo',
#        'tax_office', 'timezone', 'geo_lat', 'geo_lon', 'population',
#        'foundation_year', 'name', 'name_full', 'region_orig',
#        'region_for_join_y', 'region_for_join', 'id', 'region_settlements',
#        'municipality', 'settlement_settlements', 'type',
#        'population_settlements', 'children', 'latitude_dms', 'longitude_dms',
#        'latitude_dd', 'longitude_dd', 'oktmo_settlements', 'dadata',
#        'rosstat'],
#       dtype='object')

# %%
cols_to_drop = [
    "region_for_join", "district_for_join", "city_for_join", "settlement_for_join",
    "address", "postal_code", "country", "federal_district", "kladr_id", "fias_id",
    "fias_level", "capital_marker", "okato", "tax_office", "timezone", "population",
    "foundation_year", "id", "population_settlements", "children", "dadata", "rosstat"
]
merged_2.drop(columns=cols_to_drop, inplace=True)

# %%
(merged_2[["oktmo", "oktmo_settlements"]].notna().sum() / merged_2.shape[0]).sum()
# Out:
# 0.9321246985676516

# %%
matched = merged_2.loc[merged_2["oktmo"].notna() | merged_2["oktmo_settlements"].notna()]
rest = merged_2.loc[merged_2["oktmo"].isna() & merged_2["oktmo_settlements"].isna()]
matched.shape, rest.shape
# Out:
# ((160397, 48), (11698, 48))

# %%
rest = rest.loc[:, "kind":"end_date"]
rest.head(2)
# Out:
#     kind  category  ind_tin  ind_number first_name last_name patronymic  \
# 63     1         1      NaN         NaN        NaN       NaN        NaN
# 76     1         1      NaN         NaN        NaN       NaN        NaN
#
#                                              org_name  \
# 63  ОБЩЕСТВО С ОГРАНИЧЕННОЙ ОТВЕТСТВЕННОСТЬЮ "ВАЛЕ...
# 76  ОБЩЕСТВО С ОГРАНИЧЕННОЙ ОТВЕТСТВЕННОСТЬЮ "ФИНА...
#
#                       org_short_name       org_tin    org_number  region_code  \
# 63                     ООО "ВАЛЕРИЯ"  2.360014e+09  1.212300e+12           23
# 76  ООО "ФИНАНСОВО-ЮРИДИЧЕСКОЕ БЮРО"  2.508126e+09           NaN           25
#
#       region_name region_type district_name district_type city_name city_type  \
# 63  КРАСНОДАРСКИЙ        КРАЙ    КРЫЛОВСКИЙ           Р-Н       NaN       NaN
# 76     ПРИМОРСКИЙ        КРАЙ           NaN           NaN   НАХОДКА     ГОРОД
#
#    settlement_name settlement_type  activity_code_main  start_date    end_date
# 63      КРЫЛОВСКАЯ           СТ-ЦА                69.1  2021-08-10         NaN
# 76        ВРАНГЕЛЬ      МИКРОРАЙОН                69.1  2016-08-10  2019-05-10

# %%
rest["region"] = rest["region_name"].apply(g._normalize_region).str.upper()
rest.shape
# Out:
# (11698, 24)

# %%
cities["id"] = range(0, cities.shape[0])
cities.head(2)
# Out:
#                    address  postal_code country federal_district region_type  \
# 0  Респ Адыгея, г Адыгейск     385200.0  Россия            Южный        Респ
# 1                 г Майкоп     385000.0  Россия            Южный        Респ
#
#    region area_type area city_type      city settlement_type settlement  \
# 0  Адыгея       NaN  NaN         г  Адыгейск             NaN        NaN
# 1  Адыгея       NaN  NaN         г    Майкоп             NaN        NaN
#
#        kladr_id                               fias_id  fias_level  \
# 0  1.000002e+11  ccdfd496-8108-4655-aadd-bd228747306d           4
# 1  1.000001e+11  8cfbe842-e803-49ca-9347-1ef90481dd98           4
#
#    capital_marker         okato         oktmo  tax_office timezone    geo_lat  \
# 0               0  7.940300e+10  7.970300e+10         107    UTC+3  44.878414
# 1               2  7.940100e+10  7.970100e+10         105    UTC+3  44.609827
#
#      geo_lon  population  foundation_year region_for_join district_for_join  \
# 0  39.190289       12689           1969.0          АДЫГЕЯ               NaN
# 1  40.100661      144055           1857.0          АДЫГЕЯ               NaN
#
#   city_for_join settlement_for_join  id
# 0      АДЫГЕЙСК                 NaN   0
# 1        МАЙКОП                 NaN   1

# %%
rj1 = rest.reset_index().merge(
    cities.loc[cities["settlement"].isna(), "region_for_join":"id"],
    how="left",
    left_on=("region", "district_name", "city_name"),
    right_on=("region_for_join", "district_for_join", "city_for_join"),
    suffixes=("", "_cj1")
)
rj1.drop(columns=[col for col in rj1.columns if "_join" in col], inplace=True)
rj1.rename(columns={"id": "id_cj1"}, inplace=True)
rj1.head(2)
# Out:
#    index  kind  category  ind_tin  ind_number first_name last_name patronymic  \
# 0     63     1         1      NaN         NaN        NaN       NaN        NaN
# 1     76     1         1      NaN         NaN        NaN       NaN        NaN
#
#                                             org_name  \
# 0  ОБЩЕСТВО С ОГРАНИЧЕННОЙ ОТВЕТСТВЕННОСТЬЮ "ВАЛЕ...
# 1  ОБЩЕСТВО С ОГРАНИЧЕННОЙ ОТВЕТСТВЕННОСТЬЮ "ФИНА...
#
#                      org_short_name       org_tin    org_number  region_code  \
# 0                     ООО "ВАЛЕРИЯ"  2.360014e+09  1.212300e+12           23
# 1  ООО "ФИНАНСОВО-ЮРИДИЧЕСКОЕ БЮРО"  2.508126e+09           NaN           25
#
#      region_name region_type district_name district_type city_name city_type  \
# 0  КРАСНОДАРСКИЙ        КРАЙ    КРЫЛОВСКИЙ           Р-Н       NaN       NaN
# 1     ПРИМОРСКИЙ        КРАЙ           NaN           NaN   НАХОДКА     ГОРОД
#
#   settlement_name settlement_type  activity_code_main  start_date    end_date  \
# 0      КРЫЛОВСКАЯ           СТ-ЦА                69.1  2021-08-10         NaN
# 1        ВРАНГЕЛЬ      МИКРОРАЙОН                69.1  2016-08-10  2019-05-10
#
#           region  id_cj1
# 0  КРАСНОДАРСКИЙ     NaN
# 1     ПРИМОРСКИЙ   721.0

# %%
rj1.shape
# Out:
# (11698, 26)

# %%
rj2 = rj1.merge(
    cities.loc[(cities["area_type"] == "г") & (cities["city"].isna()), "region_for_join":"id"],
    how="left",
    left_on=("region", "district_name"),
    right_on=("region_for_join", "district_for_join"),
    suffixes=("", "_cj2")
)
rj2.drop(columns=[col for col in rj2.columns if "_join" in col], inplace=True)
rj2.rename(columns={"id": "id_cj2"}, inplace=True)
rj2.head(2)
# Out:
#    index  kind  category  ind_tin  ind_number first_name last_name patronymic  \
# 0     63     1         1      NaN         NaN        NaN       NaN        NaN
# 1     76     1         1      NaN         NaN        NaN       NaN        NaN
#
#                                             org_name  \
# 0  ОБЩЕСТВО С ОГРАНИЧЕННОЙ ОТВЕТСТВЕННОСТЬЮ "ВАЛЕ...
# 1  ОБЩЕСТВО С ОГРАНИЧЕННОЙ ОТВЕТСТВЕННОСТЬЮ "ФИНА...
#
#                      org_short_name       org_tin    org_number  region_code  \
# 0                     ООО "ВАЛЕРИЯ"  2.360014e+09  1.212300e+12           23
# 1  ООО "ФИНАНСОВО-ЮРИДИЧЕСКОЕ БЮРО"  2.508126e+09           NaN           25
#
#      region_name region_type district_name district_type city_name city_type  \
# 0  КРАСНОДАРСКИЙ        КРАЙ    КРЫЛОВСКИЙ           Р-Н       NaN       NaN
# 1     ПРИМОРСКИЙ        КРАЙ           NaN           NaN   НАХОДКА     ГОРОД
#
#   settlement_name settlement_type  activity_code_main  start_date    end_date  \
# 0      КРЫЛОВСКАЯ           СТ-ЦА                69.1  2021-08-10         NaN
# 1        ВРАНГЕЛЬ      МИКРОРАЙОН                69.1  2016-08-10  2019-05-10
#
#           region  id_cj1  id_cj2
# 0  КРАСНОДАРСКИЙ     NaN     NaN
# 1     ПРИМОРСКИЙ   721.0     NaN

# %%
rj3 = rj2.merge(
    cities.loc[(cities["area_type"] == "г") & (cities["city"].isna()), "region_for_join":"id"],
    how="left",
    left_on=("region", "city_name"),
    right_on=("region_for_join", "district_for_join"),
    suffixes=("", "_cj3")
)
rj3.drop(columns=[col for col in rj3.columns if "_join" in col], inplace=True)
rj3.rename(columns={"id": "id_cj3"}, inplace=True)
rj3.head(2)
# Out:
#    index  kind  category  ind_tin  ind_number first_name last_name patronymic  \
# 0     63     1         1      NaN         NaN        NaN       NaN        NaN
# 1     76     1         1      NaN         NaN        NaN       NaN        NaN
#
#                                             org_name  \
# 0  ОБЩЕСТВО С ОГРАНИЧЕННОЙ ОТВЕТСТВЕННОСТЬЮ "ВАЛЕ...
# 1  ОБЩЕСТВО С ОГРАНИЧЕННОЙ ОТВЕТСТВЕННОСТЬЮ "ФИНА...
#
#                      org_short_name       org_tin    org_number  region_code  \
# 0                     ООО "ВАЛЕРИЯ"  2.360014e+09  1.212300e+12           23
# 1  ООО "ФИНАНСОВО-ЮРИДИЧЕСКОЕ БЮРО"  2.508126e+09           NaN           25
#
#      region_name region_type district_name district_type city_name city_type  \
# 0  КРАСНОДАРСКИЙ        КРАЙ    КРЫЛОВСКИЙ           Р-Н       NaN       NaN
# 1     ПРИМОРСКИЙ        КРАЙ           NaN           NaN   НАХОДКА     ГОРОД
#
#   settlement_name settlement_type  activity_code_main  start_date    end_date  \
# 0      КРЫЛОВСКАЯ           СТ-ЦА                69.1  2021-08-10         NaN
# 1        ВРАНГЕЛЬ      МИКРОРАЙОН                69.1  2016-08-10  2019-05-10
#
#           region  id_cj1  id_cj2  id_cj3
# 0  КРАСНОДАРСКИЙ     NaN     NaN     NaN
# 1     ПРИМОРСКИЙ   721.0     NaN     NaN

# %%
rj4 = rj3.merge(
    cities.loc[cities["settlement"].isna() & cities["city"].notna(), "region_for_join":"id"],
    how="left",
    left_on=("region", "city_name"),
    right_on=("region_for_join", "city_for_join"),
    suffixes=("", "_cj4")
)
rj4.drop(columns=[col for col in rj4.columns if "_join" in col], inplace=True)
rj4.rename(columns={"id": "id_cj4"}, inplace=True)
rj4.head(2)
# Out:
#    index  kind  category  ind_tin  ind_number first_name last_name patronymic  \
# 0     63     1         1      NaN         NaN        NaN       NaN        NaN
# 1     76     1         1      NaN         NaN        NaN       NaN        NaN
#
#                                             org_name  \
# 0  ОБЩЕСТВО С ОГРАНИЧЕННОЙ ОТВЕТСТВЕННОСТЬЮ "ВАЛЕ...
# 1  ОБЩЕСТВО С ОГРАНИЧЕННОЙ ОТВЕТСТВЕННОСТЬЮ "ФИНА...
#
#                      org_short_name       org_tin    org_number  region_code  \
# 0                     ООО "ВАЛЕРИЯ"  2.360014e+09  1.212300e+12           23
# 1  ООО "ФИНАНСОВО-ЮРИДИЧЕСКОЕ БЮРО"  2.508126e+09           NaN           25
#
#      region_name region_type district_name district_type city_name city_type  \
# 0  КРАСНОДАРСКИЙ        КРАЙ    КРЫЛОВСКИЙ           Р-Н       NaN       NaN
# 1     ПРИМОРСКИЙ        КРАЙ           NaN           NaN   НАХОДКА     ГОРОД
#
#   settlement_name settlement_type  activity_code_main  start_date    end_date  \
# 0      КРЫЛОВСКАЯ           СТ-ЦА                69.1  2021-08-10         NaN
# 1        ВРАНГЕЛЬ      МИКРОРАЙОН                69.1  2016-08-10  2019-05-10
#
#           region  id_cj1  id_cj2  id_cj3  id_cj4
# 0  КРАСНОДАРСКИЙ     NaN     NaN     NaN     NaN
# 1     ПРИМОРСКИЙ   721.0     NaN     NaN   721.0

# %%
rj4 = rj4.merge(pd.concat(
        (socr[["name", "name_full"]].apply(lambda x: x.str.upper()).drop_duplicates("name"),
         pd.DataFrame({"name": socr["name_full"].drop_duplicates().str.upper(), "name_full": socr["name_full"].drop_duplicates().str.upper()})
        )
    ),
    how="left",
    left_on="district_type",
    right_on="name")
rj4["district_type"] = rj4["name_full"]

# %%
rj4["district_for_join"] = rj4["district_name"] + " " + rj4["district_type"]

# %%
settlements_for_rj4 = pd.read_csv("settlements_12032021/data.csv")
settlements_for_rj4["municipality_for_join"] = settlements_for_rj4["municipality"].str.upper()

# %%
settlements_for_rj4.drop_duplicates(subset=("municipality", "region", "settlement"), keep=False)
# Out:
#             id               region                municipality  \
# 0            0    Орловская область                  Болховский
# 1            1      Республика Крым                      Алушта
# 2            2     Липецкая область       Лев-Толстовский район
# 3            3     Тверская область         Селижаровский район
# 4            4      Томская область          Парабельский район
# ...        ...                  ...                         ...
# 155916  155916  Ульяновская область           Вешкаймский район
# 155917  155917    Псковская область            Палкинский район
# 155918  155918    Псковская область             Себежский район
# 155919  155919     Тульская область  рабочий пос. Новогуровский
# 155920  155920   Краснодарский край          Город-курорт Анапа
#
#            settlement   type  population  children latitude_dms longitude_dms  \
# 0          Колонтаева      д           0         0     53.22.07     035.54.36
# 1             Пушкино      с         273         0     44.35.45     034.20.27
# 2            Барятино      с           7         1     53.15.46     039.30.14
# 3              Хилово      д           2         0     56.54.20     033.25.09
# 4           Басмасово      д           6         0     58.38.12     082.02.40
# ...               ...    ...         ...       ...          ...           ...
# 155916       Ребровка      д           0         0     53.59.12     046.48.35
# 155917        Шадрица      д           1         0     57.29.03     028.08.48
# 155918    Овчинниково      д           0         0     56.19.48     028.26.17
# 155919  Новогуровский     рп        3398       305     54.28.03     037.20.19
# 155920  Гостагаевская  ст-ца       12566      2980     45.01.21     037.30.15
#
#         latitude_dd  longitude_dd         oktmo  dadata  rosstat  \
# 0         53.368611     35.910000  5.460442e+10       0        1
# 1         44.595833     34.340833  3.570300e+10       0        1
# 2         53.262778     39.503889  4.263641e+10       0        1
# 3         56.905556     33.419167  2.865043e+10       0        1
# 4         58.636667     82.044444  6.964444e+10       0        1
# ...             ...           ...           ...     ...      ...
# 155916    53.986667     46.809722  7.360744e+10       0        1
# 155917    57.484167     28.146667  5.863742e+10       0        1
# 155918    56.330000     28.438056  5.865410e+10       0        1
# 155919    54.467500     37.338611  7.070200e+10       1        0
# 155920    45.022500     37.504167  3.703000e+09       1        0
#
#              municipality_for_join
# 0                       БОЛХОВСКИЙ
# 1                           АЛУШТА
# 2            ЛЕВ-ТОЛСТОВСКИЙ РАЙОН
# 3              СЕЛИЖАРОВСКИЙ РАЙОН
# 4               ПАРАБЕЛЬСКИЙ РАЙОН
# ...                            ...
# 155916           ВЕШКАЙМСКИЙ РАЙОН
# 155917            ПАЛКИНСКИЙ РАЙОН
# 155918             СЕБЕЖСКИЙ РАЙОН
# 155919  РАБОЧИЙ ПОС. НОВОГУРОВСКИЙ
# 155920          ГОРОД-КУРОРТ АНАПА
#
# [148362 rows x 15 columns]

# %%
settlements_for_rj4["region_for_join"] = settlements_for_rj4["region"].apply(remove_type_from_region_name).str.upper()
settlements_for_rj4["settlement_for_join"] = settlements_for_rj4["settlement"].str.upper()

# %%
rj5 = rj4.merge(
    settlements_for_rj4.drop_duplicates(subset=("municipality", "region", "settlement"), keep=False),
    how="left",
    left_on=("region", "district_for_join", "settlement_name"),
    right_on=("region_for_join", "municipality_for_join", "settlement_for_join"),
    suffixes=("", "_cj5")
)
rj5.drop(columns=[col for col in rj5.columns if "_join" in col], inplace=True)
rj5.rename(columns={"id": "id_cj5"}, inplace=True)
rj5.head(2)
# Out:
#    index  kind  category  ind_tin  ind_number first_name last_name patronymic  \
# 0     63     1         1      NaN         NaN        NaN       NaN        NaN
# 1     76     1         1      NaN         NaN        NaN       NaN        NaN
#
#                                             org_name  \
# 0  ОБЩЕСТВО С ОГРАНИЧЕННОЙ ОТВЕТСТВЕННОСТЬЮ "ВАЛЕ...
# 1  ОБЩЕСТВО С ОГРАНИЧЕННОЙ ОТВЕТСТВЕННОСТЬЮ "ФИНА...
#
#                      org_short_name       org_tin    org_number  region_code  \
# 0                     ООО "ВАЛЕРИЯ"  2.360014e+09  1.212300e+12           23
# 1  ООО "ФИНАНСОВО-ЮРИДИЧЕСКОЕ БЮРО"  2.508126e+09           NaN           25
#
#      region_name region_type district_name district_type city_name city_type  \
# 0  КРАСНОДАРСКИЙ        КРАЙ    КРЫЛОВСКИЙ         РАЙОН       NaN       NaN
# 1     ПРИМОРСКИЙ        КРАЙ           NaN           NaN   НАХОДКА     ГОРОД
#
#   settlement_name settlement_type  activity_code_main  start_date    end_date  \
# 0      КРЫЛОВСКАЯ           СТ-ЦА                69.1  2021-08-10         NaN
# 1        ВРАНГЕЛЬ      МИКРОРАЙОН                69.1  2016-08-10  2019-05-10
#
#           region  id_cj1  id_cj2  id_cj3  id_cj4 name name_full    id_cj5  \
# 0  КРАСНОДАРСКИЙ     NaN     NaN     NaN     NaN  Р-Н     РАЙОН  109043.0
# 1     ПРИМОРСКИЙ   721.0     NaN     NaN   721.0  NaN       NaN       NaN
#
#            region_cj5      municipality  settlement   type  population  \
# 0  Краснодарский край  Крыловский район  Крыловская  ст-ца     12725.0
# 1                 NaN               NaN         NaN    NaN         NaN
#
#    children latitude_dms longitude_dms  latitude_dd  longitude_dd  \
# 0    2376.0     46.19.15     039.57.18    46.320833        39.955
# 1       NaN          NaN           NaN          NaN           NaN
#
#           oktmo  dadata  rosstat
# 0  3.624411e+09     0.0      1.0
# 1           NaN     NaN      NaN

# %%
rj5["district_for_join"] = rj5["district_name"]
rj5["city_for_join"] = rj5["city_type"] + " " + rj5["city_name"]

# %%
rj6 = rj5.merge(
    settlements_for_rj4.drop_duplicates(subset=("municipality", "region", "settlement"), keep=False),
    how="left",
    left_on=("region", "district_for_join", "settlement_name"),
    right_on=("region_for_join", "municipality_for_join", "settlement_for_join"),
    suffixes=("", "_cj6")
)
rj6.drop(columns=[col for col in rj6.columns if "_join" in col], inplace=True)
rj6.rename(columns={"id": "id_cj6"}, inplace=True)
rj6.head(2)
# Out:
#    index  kind  category  ind_tin  ind_number first_name last_name patronymic  \
# 0     63     1         1      NaN         NaN        NaN       NaN        NaN
# 1     76     1         1      NaN         NaN        NaN       NaN        NaN
#
#                                             org_name  \
# 0  ОБЩЕСТВО С ОГРАНИЧЕННОЙ ОТВЕТСТВЕННОСТЬЮ "ВАЛЕ...
# 1  ОБЩЕСТВО С ОГРАНИЧЕННОЙ ОТВЕТСТВЕННОСТЬЮ "ФИНА...
#
#                      org_short_name       org_tin    org_number  region_code  \
# 0                     ООО "ВАЛЕРИЯ"  2.360014e+09  1.212300e+12           23
# 1  ООО "ФИНАНСОВО-ЮРИДИЧЕСКОЕ БЮРО"  2.508126e+09           NaN           25
#
#      region_name region_type district_name district_type city_name city_type  \
# 0  КРАСНОДАРСКИЙ        КРАЙ    КРЫЛОВСКИЙ         РАЙОН       NaN       NaN
# 1     ПРИМОРСКИЙ        КРАЙ           NaN           NaN   НАХОДКА     ГОРОД
#
#   settlement_name settlement_type  activity_code_main  start_date    end_date  \
# 0      КРЫЛОВСКАЯ           СТ-ЦА                69.1  2021-08-10         NaN
# 1        ВРАНГЕЛЬ      МИКРОРАЙОН                69.1  2016-08-10  2019-05-10
#
#           region  id_cj1  id_cj2  id_cj3  id_cj4 name name_full    id_cj5  \
# 0  КРАСНОДАРСКИЙ     NaN     NaN     NaN     NaN  Р-Н     РАЙОН  109043.0
# 1     ПРИМОРСКИЙ   721.0     NaN     NaN   721.0  NaN       NaN       NaN
#
#            region_cj5      municipality  settlement   type  population  \
# 0  Краснодарский край  Крыловский район  Крыловская  ст-ца     12725.0
# 1                 NaN               NaN         NaN    NaN         NaN
#
#    children latitude_dms longitude_dms  latitude_dd  longitude_dd  \
# 0    2376.0     46.19.15     039.57.18    46.320833        39.955
# 1       NaN          NaN           NaN          NaN           NaN
#
#           oktmo  dadata  rosstat  id_cj6 region_cj6 municipality_cj6  \
# 0  3.624411e+09     0.0      1.0     NaN        NaN              NaN
# 1           NaN     NaN      NaN     NaN        NaN              NaN
#
#   settlement_cj6 type_cj6  population_cj6  children_cj6 latitude_dms_cj6  \
# 0            NaN      NaN             NaN           NaN              NaN
# 1            NaN      NaN             NaN           NaN              NaN
#
#   longitude_dms_cj6  latitude_dd_cj6  longitude_dd_cj6  oktmo_cj6  dadata_cj6  \
# 0               NaN              NaN               NaN        NaN         NaN
# 1               NaN              NaN               NaN        NaN         NaN
#
#    rosstat_cj6
# 0          NaN
# 1          NaN

# %%
rj6.notna().sum()
# Out:
# index                 11698
# kind                  11698
# category              11698
# ind_tin                8184
# ind_number             1657
# first_name             8184
# last_name              8184
# patronymic             8130
# org_name               3514
# org_short_name         3498
# org_tin                3514
# org_number              491
# region_code           11698
# region_name           11678
# region_type           11678
# district_name          7966
# district_type          7966
# city_name              6203
# city_type              6203
# settlement_name        6517
# settlement_type        6517
# activity_code_main    11698
# start_date            11698
# end_date               4720
# region                11489
# id_cj1                 2534
# id_cj2                  218
# id_cj3                 1711
# id_cj4                 3824
# name                   7966
# name_full              7966
# id_cj5                 1481
# region_cj5             1481
# municipality           1481
# settlement             1481
# type                   1481
# population             1481
# children               1481
# latitude_dms           1481
# longitude_dms          1481
# latitude_dd            1481
# longitude_dd           1481
# oktmo                  1481
# dadata                 1481
# rosstat                1481
# id_cj6                  837
# region_cj6              837
# municipality_cj6        837
# settlement_cj6          837
# type_cj6                837
# population_cj6          837
# children_cj6            837
# latitude_dms_cj6        837
# longitude_dms_cj6       837
# latitude_dd_cj6         837
# longitude_dd_cj6        837
# oktmo_cj6               837
# dadata_cj6              837
# rosstat_cj6             837
# dtype: int64

# %%
rj6[[c for c in rj6.columns if "id_cj" in c]].notna().sum(axis=1).value_counts()[0] / rsmp.shape[0]
# Out:
# 0.018925593422237718

# %%
rj6.loc[rj6[[c for c in rj6.columns if "id_cj" in c]].notna().sum(axis=1) == 0]
# Out:
#         index  kind  category       ind_tin    ind_number first_name  \
# 2         104     1         1           NaN           NaN        NaN
# 7         312     1         1           NaN           NaN        NaN
# 12        454     2         1  2.245023e+11  3.222202e+14     РУСЛАН
# 13        475     2         1  2.437009e+11           NaN     АНЖЕЛА
# 15        531     2         1  3.459193e+11  3.229401e+14      ОЛЬГА
# ...       ...   ...       ...           ...           ...        ...
# 11684  171952     2         1  6.410018e+11  3.226457e+14      ЖАНАТ
# 11691  172004     2         1  7.132103e+11           NaN   ВЛАДИМИР
# 11692  172018     2         1  7.452040e+11           NaN     МАКСИМ
# 11694  172052     2         1  7.729914e+11  3.227746e+14    АЛЕКСЕЙ
# 11695  172059     2         1  7.733772e+11           NaN      ОЛЬГА
#
#         last_name      patronymic  \
# 2             NaN             NaN
# 7             NaN             NaN
# 12        ГАДЖИЕВ     ЛАГМАН ОГЛЫ
# 13     ФИЛИМОНОВА  КОНСТАНТИНОВНА
# 15      МЕДВЕДЕВА    ВЛАДИМИРОВНА
# ...           ...             ...
# 11684   ЖАНТАЛИЕВ       КАНАТОВИЧ
# 11691       ИСАЕВ      НИКОЛАЕВИЧ
# 11692    БИККУЛОВ       РАМИЛОВИЧ
# 11694       БОЙКО      ВАЛЕРЬЕВИЧ
# 11695  ЗАВРАЖНОВА   АЛЕКСАНДРОВНА
#
#                                                 org_name org_short_name  \
# 2      ОБЩЕСТВО С ОГРАНИЧЕННОЙ ОТВЕТСТВЕННОСТЬЮ "КУАТ...  ООО "КУАТТРО"
# 7      ОБЩЕСТВО С ОГРАНИЧЕННОЙ ОТВЕТСТВЕННОСТЬЮ "АНЕЛАН"   ООО "АНЕЛАН"
# 12                                                   NaN            NaN
# 13                                                   NaN            NaN
# 15                                                   NaN            NaN
# ...                                                  ...            ...
# 11684                                                NaN            NaN
# 11691                                                NaN            NaN
# 11692                                                NaN            NaN
# 11694                                                NaN            NaN
# 11695                                                NaN            NaN
#
#             org_tin  org_number  region_code         region_name region_type  \
# 2      3.510009e+09         NaN           35         ВОЛОГОДСКАЯ     ОБЛАСТЬ
# 7      7.733244e+09         NaN           77              МОСКВА       ГОРОД
# 12              NaN         NaN           22           АЛТАЙСКИЙ        КРАЙ
# 13              NaN         NaN           24        КРАСНОЯРСКИЙ        КРАЙ
# 15              NaN         NaN           94  ЛУГАНСКАЯ НАРОДНАЯ       РЕСП.
# ...             ...         ...          ...                 ...         ...
# 11684           NaN         NaN           64         САРАТОВСКАЯ        ОБЛ.
# 11691           NaN         NaN           71            ТУЛЬСКАЯ     ОБЛАСТЬ
# 11692           NaN         NaN           74         ЧЕЛЯБИНСКАЯ     ОБЛАСТЬ
# 11694           NaN         NaN           77              МОСКВА          Г.
# 11695           NaN         NaN           71            ТУЛЬСКАЯ     ОБЛАСТЬ
#
#          district_name district_type city_name city_type   settlement_name  \
# 2            КАДУЙСКИЙ         РАЙОН       NaN       NaN             КАДУЙ
# 7      КРАСНОПАХОРСКОЕ     ПОСЕЛЕНИЕ       NaN       NaN            БЫЛОВО
# 12           ЗОНАЛЬНЫЙ         РАЙОН       NaN       NaN          БУЛАНИХА
# 13       НОВОСЕЛОВСКИЙ         РАЙОН       NaN       NaN        НОВОСЕЛОВО
# 15                 NaN           NaN  ЛУТУГИНО        Г.               NaN
# ...                ...           ...       ...       ...               ...
# 11684     ДЕРГАЧЕВСКИЙ         РАЙОН       NaN       NaN         ВОСТОЧНЫЙ
# 11691         ЧЕРНСКИЙ         РАЙОН       NaN       NaN             ЧЕРНЬ
# 11692       СОСНОВСКИЙ         РАЙОН       NaN       NaN  СМОЛИНО Ж-Д. СТ.
# 11694       ВНУКОВСКОЕ       ПОСЕЛОК       NaN       NaN          ИЗВАРИНО
# 11695   НОВОМОСКОВСКИЙ         РАЙОН       NaN       NaN          ГРЕМЯЧЕЕ
#
#        settlement_type  activity_code_main  start_date    end_date  \
# 2      РАБОЧИЙ ПОСЕЛОК                69.1  2016-08-10         NaN
# 7                 СЕЛО                69.1  2016-11-10         NaN
# 12                  С.                69.1  2022-11-10         NaN
# 13                СЕЛО                69.1  2017-04-10         NaN
# 15                 NaN                69.1  2023-01-10  2023-02-10
# ...                ...                 ...         ...         ...
# 11684               П.                69.1  2022-06-10         NaN
# 11691  РАБОЧИЙ ПОСЕЛОК                69.1  2016-08-10         NaN
# 11692          ПОСЕЛОК                69.1  2016-08-10         NaN
# 11694               Д.                69.1  2022-06-10         NaN
# 11695             СЕЛО                69.1  2016-08-10  2017-12-10
#
#              region  id_cj1  id_cj2  id_cj3  id_cj4       name  name_full  \
# 2       ВОЛОГОДСКАЯ     NaN     NaN     NaN     NaN      РАЙОН      РАЙОН
# 7            МОСКВА     NaN     NaN     NaN     NaN  ПОСЕЛЕНИЕ  ПОСЕЛЕНИЕ
# 12        АЛТАЙСКИЙ     NaN     NaN     NaN     NaN        Р-Н      РАЙОН
# 13     КРАСНОЯРСКИЙ     NaN     NaN     NaN     NaN      РАЙОН      РАЙОН
# 15             <NA>     NaN     NaN     NaN     NaN        NaN        NaN
# ...             ...     ...     ...     ...     ...        ...        ...
# 11684   САРАТОВСКАЯ     NaN     NaN     NaN     NaN        Р-Н      РАЙОН
# 11691      ТУЛЬСКАЯ     NaN     NaN     NaN     NaN      РАЙОН      РАЙОН
# 11692   ЧЕЛЯБИНСКАЯ     NaN     NaN     NaN     NaN      РАЙОН      РАЙОН
# 11694        МОСКВА     NaN     NaN     NaN     NaN         П.    ПОСЕЛОК
# 11695      ТУЛЬСКАЯ     NaN     NaN     NaN     NaN      РАЙОН      РАЙОН
#
#        id_cj5 region_cj5 municipality settlement type  population  children  \
# 2         NaN        NaN          NaN        NaN  NaN         NaN       NaN
# 7         NaN        NaN          NaN        NaN  NaN         NaN       NaN
# 12        NaN        NaN          NaN        NaN  NaN         NaN       NaN
# 13        NaN        NaN          NaN        NaN  NaN         NaN       NaN
# 15        NaN        NaN          NaN        NaN  NaN         NaN       NaN
# ...       ...        ...          ...        ...  ...         ...       ...
# 11684     NaN        NaN          NaN        NaN  NaN         NaN       NaN
# 11691     NaN        NaN          NaN        NaN  NaN         NaN       NaN
# 11692     NaN        NaN          NaN        NaN  NaN         NaN       NaN
# 11694     NaN        NaN          NaN        NaN  NaN         NaN       NaN
# 11695     NaN        NaN          NaN        NaN  NaN         NaN       NaN
#
#       latitude_dms longitude_dms  latitude_dd  longitude_dd  oktmo  dadata  \
# 2              NaN           NaN          NaN           NaN    NaN     NaN
# 7              NaN           NaN          NaN           NaN    NaN     NaN
# 12             NaN           NaN          NaN           NaN    NaN     NaN
# 13             NaN           NaN          NaN           NaN    NaN     NaN
# 15             NaN           NaN          NaN           NaN    NaN     NaN
# ...            ...           ...          ...           ...    ...     ...
# 11684          NaN           NaN          NaN           NaN    NaN     NaN
# 11691          NaN           NaN          NaN           NaN    NaN     NaN
# 11692          NaN           NaN          NaN           NaN    NaN     NaN
# 11694          NaN           NaN          NaN           NaN    NaN     NaN
# 11695          NaN           NaN          NaN           NaN    NaN     NaN
#
#        rosstat  id_cj6 region_cj6 municipality_cj6 settlement_cj6 type_cj6  \
# 2          NaN     NaN        NaN              NaN            NaN      NaN
# 7          NaN     NaN        NaN              NaN            NaN      NaN
# 12         NaN     NaN        NaN              NaN            NaN      NaN
# 13         NaN     NaN        NaN              NaN            NaN      NaN
# 15         NaN     NaN        NaN              NaN            NaN      NaN
# ...        ...     ...        ...              ...            ...      ...
# 11684      NaN     NaN        NaN              NaN            NaN      NaN
# 11691      NaN     NaN        NaN              NaN            NaN      NaN
# 11692      NaN     NaN        NaN              NaN            NaN      NaN
# 11694      NaN     NaN        NaN              NaN            NaN      NaN
# 11695      NaN     NaN        NaN              NaN            NaN      NaN
#
#        population_cj6  children_cj6 latitude_dms_cj6 longitude_dms_cj6  \
# 2                 NaN           NaN              NaN               NaN
# 7                 NaN           NaN              NaN               NaN
# 12                NaN           NaN              NaN               NaN
# 13                NaN           NaN              NaN               NaN
# 15                NaN           NaN              NaN               NaN
# ...               ...           ...              ...               ...
# 11684             NaN           NaN              NaN               NaN
# 11691             NaN           NaN              NaN               NaN
# 11692             NaN           NaN              NaN               NaN
# 11694             NaN           NaN              NaN               NaN
# 11695             NaN           NaN              NaN               NaN
#
#        latitude_dd_cj6  longitude_dd_cj6  oktmo_cj6  dadata_cj6  rosstat_cj6
# 2                  NaN               NaN        NaN         NaN          NaN
# 7                  NaN               NaN        NaN         NaN          NaN
# 12                 NaN               NaN        NaN         NaN          NaN
# 13                 NaN               NaN        NaN         NaN          NaN
# 15                 NaN               NaN        NaN         NaN          NaN
# ...                ...               ...        ...         ...          ...
# 11684              NaN               NaN        NaN         NaN          NaN
# 11691              NaN               NaN        NaN         NaN          NaN
# 11692              NaN               NaN        NaN         NaN          NaN
# 11694              NaN               NaN        NaN         NaN          NaN
# 11695              NaN               NaN        NaN         NaN          NaN
#
# [3257 rows x 59 columns]

# %%
pd.DataFrame(rj6.loc[rj6[[c for c in rj6.columns if "id_cj" in c]].notna().sum(axis=1) == 0]["city_name"].value_counts()).head(20)
# Out:
#                count
# city_name
# МОСКОВСКИЙ       167
# МАРКОВА           37
# ШАХОВСКАЯ         26
# МАЛАХОВКА         22
# ПРОМЫШЛЕННАЯ      22
# КЛИМОВСК          20
# КОЛЬЦОВО          19
# ТОМИЛИНО          17
# КРАСКОВО          15
# МАКЕЕВКА          14
# ИНКЕРМАН          11
# ОКТЯБРЬСКИЙ       11
# СИРИУС            10
# ЧУНСКИЙ           10
# ЛИКИНО-ДУЛЁВО      9
# МАРИУПОЛЬ          8
# ЛОТОШИНО           8
# ЯШКИНО             8
# ШЕРЕГЕШ            8
# ЗЕЛЕНОГОРСКИЙ      7

# %%
rj6.loc[rj6["city_name"] == "МОСКОВСКИЙ"]
# Out:
#         index  kind  category       ind_tin    ind_number first_name  \
# 71       1298     2         1  2.129142e+11           NaN       ЮЛИЯ
# 107      1651     2         1  7.729720e+11           NaN       ЮЛИЯ
# 242      3828     1         1           NaN           NaN        NaN
# 420      6439     2         1  5.190065e+10           NaN      НАДИР
# 425      6549     2         1  3.435172e+11  3.227746e+14  ЕКАТЕРИНА
# ...       ...   ...       ...           ...           ...        ...
# 11323  166411     1         1           NaN           NaN        NaN
# 11325  166413     1         1           NaN           NaN        NaN
# 11472  168508     2         1  5.603058e+11           NaN    АЛЬБЕРТ
# 11486  168631     2         1  7.720731e+11           NaN  ВЛАДИСЛАВ
# 11553  169992     2         1  1.101145e+11  3.191121e+14     ЛЮБОВЬ
#
#         last_name   patronymic  \
# 71        ВДОВИНА   ЛЕОНИДОВНА
# 107      СЕРГЕЕВА    СЕРГЕЕВНА
# 242           NaN          NaN
# 420        КАЗИЕВ    ЗАМИРОВИЧ
# 425      БАРАНОВА   ВИКТОРОВНА
# ...           ...          ...
# 11323         NaN          NaN
# 11325         NaN          NaN
# 11472  ГИМАТДИНОВ  АЛЬБЕРТОВИЧ
# 11486    ЕФИМОВИЧ     ИГОРЕВИЧ
# 11553      ШЕГУТА   НИКОЛАЕВНА
#
#                                                 org_name  \
# 71                                                   NaN
# 107                                                  NaN
# 242     ОБЩЕСТВО С ОГРАНИЧЕННОЙ ОТВЕТСТВЕННОСТЬЮ "СОНАР"
# 420                                                  NaN
# 425                                                  NaN
# ...                                                  ...
# 11323  ОБЩЕСТВО С ОГРАНИЧЕННОЙ ОТВЕТСТВЕННОСТЬЮ "ПРОФ...
# 11325  ОБЩЕСТВО С ОГРАНИЧЕННОЙ ОТВЕТСТВЕННОСТЬЮ "ПРАВ...
# 11472                                                NaN
# 11486                                                NaN
# 11553                                                NaN
#
#                         org_short_name       org_tin  org_number  region_code  \
# 71                                 NaN           NaN         NaN           77
# 107                                NaN           NaN         NaN           77
# 242                        ООО "СОНАР"  7.751108e+09         NaN           77
# 420                                NaN           NaN         NaN           77
# 425                                NaN           NaN         NaN           77
# ...                                ...           ...         ...          ...
# 11323                ООО "ПРОФИТ-ПЛЮС"  7.751068e+09         NaN           77
# 11325  ООО "ПРАВОВАЯ КОМПАНИЯ "АСПЕКТ"  7.751178e+09         NaN           77
# 11472                              NaN           NaN         NaN           77
# 11486                              NaN           NaN         NaN           77
# 11553                              NaN           NaN         NaN           77
#
#       region_name region_type district_name district_type   city_name  \
# 71         МОСКВА          Г.    МОСКОВСКИЙ       ПОСЕЛОК  МОСКОВСКИЙ
# 107        МОСКВА       ГОРОД    МОСКОВСКИЙ     ПОСЕЛЕНИЕ  МОСКОВСКИЙ
# 242        МОСКВА       ГОРОД           NaN           NaN  МОСКОВСКИЙ
# 420        МОСКВА       ГОРОД    МОСКОВСКИЙ     ПОСЕЛЕНИЕ  МОСКОВСКИЙ
# 425        МОСКВА          Г.    МОСКОВСКИЙ       ПОСЕЛОК  МОСКОВСКИЙ
# ...           ...         ...           ...           ...         ...
# 11323      МОСКВА       ГОРОД           NaN           NaN  МОСКОВСКИЙ
# 11325      МОСКВА       ГОРОД    МОСКОВСКИЙ     ПОСЕЛЕНИЕ  МОСКОВСКИЙ
# 11472      МОСКВА       ГОРОД    МОСКОВСКИЙ     ПОСЕЛЕНИЕ  МОСКОВСКИЙ
# 11486      МОСКВА       ГОРОД    МОСКОВСКИЙ     ПОСЕЛЕНИЕ  МОСКОВСКИЙ
# 11553      МОСКВА       ГОРОД    МОСКОВСКИЙ     ПОСЕЛЕНИЕ  МОСКОВСКИЙ
#
#       city_type settlement_name settlement_type  activity_code_main  \
# 71           Г.             NaN             NaN                69.1
# 107       ГОРОД             NaN             NaN                69.1
# 242       ГОРОД             NaN             NaN                69.1
# 420       ГОРОД             NaN             NaN                69.1
# 425          Г.             NaN             NaN                69.1
# ...         ...             ...             ...                 ...
# 11323     ГОРОД             NaN             NaN                69.1
# 11325     ГОРОД             NaN             NaN                69.1
# 11472     ГОРОД             NaN             NaN                69.1
# 11486     ГОРОД             NaN             NaN                69.1
# 11553     ГОРОД             NaN             NaN                69.1
#
#        start_date end_date  region  id_cj1  id_cj2  id_cj3  id_cj4       name  \
# 71     2021-03-10      NaN  МОСКВА     NaN     NaN     NaN     NaN         П.
# 107    2021-06-10      NaN  МОСКВА     NaN     NaN     NaN     NaN  ПОСЕЛЕНИЕ
# 242    2017-12-10      NaN  МОСКВА     NaN     NaN     NaN     NaN        NaN
# 420    2021-04-10      NaN  МОСКВА     NaN     NaN     NaN     NaN  ПОСЕЛЕНИЕ
# 425    2022-02-10      NaN  МОСКВА     NaN     NaN     NaN     NaN         П.
# ...           ...      ...     ...     ...     ...     ...     ...        ...
# 11323  2017-09-10      NaN  МОСКВА     NaN     NaN     NaN     NaN        NaN
# 11325  2020-04-10      NaN  МОСКВА     NaN     NaN     NaN     NaN  ПОСЕЛЕНИЕ
# 11472  2019-05-10      NaN  МОСКВА     NaN     NaN     NaN     NaN  ПОСЕЛЕНИЕ
# 11486  2019-06-10      NaN  МОСКВА     NaN     NaN     NaN     NaN  ПОСЕЛЕНИЕ
# 11553  2023-03-10      NaN  МОСКВА     NaN     NaN     NaN     NaN  ПОСЕЛЕНИЕ
#
#        name_full  id_cj5 region_cj5 municipality settlement type  population  \
# 71       ПОСЕЛОК     NaN        NaN          NaN        NaN  NaN         NaN
# 107    ПОСЕЛЕНИЕ     NaN        NaN          NaN        NaN  NaN         NaN
# 242          NaN     NaN        NaN          NaN        NaN  NaN         NaN
# 420    ПОСЕЛЕНИЕ     NaN        NaN          NaN        NaN  NaN         NaN
# 425      ПОСЕЛОК     NaN        NaN          NaN        NaN  NaN         NaN
# ...          ...     ...        ...          ...        ...  ...         ...
# 11323        NaN     NaN        NaN          NaN        NaN  NaN         NaN
# 11325  ПОСЕЛЕНИЕ     NaN        NaN          NaN        NaN  NaN         NaN
# 11472  ПОСЕЛЕНИЕ     NaN        NaN          NaN        NaN  NaN         NaN
# 11486  ПОСЕЛЕНИЕ     NaN        NaN          NaN        NaN  NaN         NaN
# 11553  ПОСЕЛЕНИЕ     NaN        NaN          NaN        NaN  NaN         NaN
#
#        children latitude_dms longitude_dms  latitude_dd  longitude_dd  oktmo  \
# 71          NaN          NaN           NaN          NaN           NaN    NaN
# 107         NaN          NaN           NaN          NaN           NaN    NaN
# 242         NaN          NaN           NaN          NaN           NaN    NaN
# 420         NaN          NaN           NaN          NaN           NaN    NaN
# 425         NaN          NaN           NaN          NaN           NaN    NaN
# ...         ...          ...           ...          ...           ...    ...
# 11323       NaN          NaN           NaN          NaN           NaN    NaN
# 11325       NaN          NaN           NaN          NaN           NaN    NaN
# 11472       NaN          NaN           NaN          NaN           NaN    NaN
# 11486       NaN          NaN           NaN          NaN           NaN    NaN
# 11553       NaN          NaN           NaN          NaN           NaN    NaN
#
#        dadata  rosstat  id_cj6 region_cj6 municipality_cj6 settlement_cj6  \
# 71        NaN      NaN     NaN        NaN              NaN            NaN
# 107       NaN      NaN     NaN        NaN              NaN            NaN
# 242       NaN      NaN     NaN        NaN              NaN            NaN
# 420       NaN      NaN     NaN        NaN              NaN            NaN
# 425       NaN      NaN     NaN        NaN              NaN            NaN
# ...       ...      ...     ...        ...              ...            ...
# 11323     NaN      NaN     NaN        NaN              NaN            NaN
# 11325     NaN      NaN     NaN        NaN              NaN            NaN
# 11472     NaN      NaN     NaN        NaN              NaN            NaN
# 11486     NaN      NaN     NaN        NaN              NaN            NaN
# 11553     NaN      NaN     NaN        NaN              NaN            NaN
#
#       type_cj6  population_cj6  children_cj6 latitude_dms_cj6  \
# 71         NaN             NaN           NaN              NaN
# 107        NaN             NaN           NaN              NaN
# 242        NaN             NaN           NaN              NaN
# 420        NaN             NaN           NaN              NaN
# 425        NaN             NaN           NaN              NaN
# ...        ...             ...           ...              ...
# 11323      NaN             NaN           NaN              NaN
# 11325      NaN             NaN           NaN              NaN
# 11472      NaN             NaN           NaN              NaN
# 11486      NaN             NaN           NaN              NaN
# 11553      NaN             NaN           NaN              NaN
#
#       longitude_dms_cj6  latitude_dd_cj6  longitude_dd_cj6  oktmo_cj6  \
# 71                  NaN              NaN               NaN        NaN
# 107                 NaN              NaN               NaN        NaN
# 242                 NaN              NaN               NaN        NaN
# 420                 NaN              NaN               NaN        NaN
# 425                 NaN              NaN               NaN        NaN
# ...                 ...              ...               ...        ...
# 11323               NaN              NaN               NaN        NaN
# 11325               NaN              NaN               NaN        NaN
# 11472               NaN              NaN               NaN        NaN
# 11486               NaN              NaN               NaN        NaN
# 11553               NaN              NaN               NaN        NaN
#
#        dadata_cj6  rosstat_cj6
# 71            NaN          NaN
# 107           NaN          NaN
# 242           NaN          NaN
# 420           NaN          NaN
# 425           NaN          NaN
# ...           ...          ...
# 11323         NaN          NaN
# 11325         NaN          NaN
# 11472         NaN          NaN
# 11486         NaN          NaN
# 11553         NaN          NaN
#
# [167 rows x 59 columns]

# %%
cities.loc[cities["city_for_join"] == "ЩЁЛКОВО"]["city_for_join"].str.replace("Ё", "Е")
# Out:
# 579    ЩЕЛКОВО
# Name: city_for_join, dtype: object

# %%
(6205 - 829 - 1980) / rsmp.shape[0]
# Out:
# 0.019733286847380807

# %%
regions_standard = cities["region"].dropna().unique()
def get_region(name):
    if pd.isna(name):
        return np.nan
    
    if name in regions_standard:
        return name
    
    match, score = process.extractOne(name, regions_standard)
    if score > 80:
        return match
    
    return np.nan

unique_regions = rest["region_name"].dropna().unique()
regions_mapping = {
    "region_name": unique_regions,
    "region_for_join": [get_region(x) for x in unique_regions],
}
regions_mapping_table = pd.DataFrame(regions_mapping)
regions_mapping_table.isna().sum()
# Out:
# region_name        0
# region_for_join    5
# dtype: int64

# %%
class Geonormalizer:
    THRES = 80
    
    def __init__(self):
        self._settlements = pd.read_csv("settlements_12032021/data.csv")
        self._cities = pd.read_csv("city.csv")
        self._regions = None
        self._cities_index = None
        self._settlements_standard = None
        self._addresses_cache = {}
        self._regions_cache = {}
        
        self._get_regions()
        self._prepare_cities()
        self._prepare_settlements()        
    
    def _get_regions(self):
        self._regions = self._cities["region"].unique()
        
    def _prepare_cities(self):
        cols_to_uppercase = ["region", "area", "city", "settlement"]
        new_cols = [f"{x}_search" for x in cols_to_uppercase]
        self._cities[new_cols] = self._cities[cols_to_uppercase].apply(lambda x: x.str.upper())
    
    def _prepare_settlements(self):
        self._settlements["region_name"] = self._settlements["region"].apply(self._normalize_region)
        cols_to_uppercase = ["region_name", "municipality", "settlement"]
        new_cols = [f"{x}_search" for x in cols_to_uppercase]
        self._settlements[new_cols] = self._settlements[cols_to_uppercase].apply(lambda x: x.str.upper())
        
    def _normalize_region(self, region_name: str) -> str:
        if region_name == "" or pd.isna(region_name):
            return None
        
        cached_region = self._regions_cache.get(region_name)
        if cached_region:
            return cached_region
        
        types = ["область", "Республика", "республика", "край", "автономный округ", "автономная область"]
        for t in types:
            search = region_name.replace(t, "")

        search = region_name.strip()
        
        match, score = process.extractOne(search, self._regions)
        if score > self.THRES:
            self._regions_cache[region_name] = match
            return match
        
        return pd.NA
    
    def _search_by_area_and_city(self, region_name, row):
        cond = (self._cities["region"] == region_name)
        if row["district_name"] != "":
            cond = cond & (self._cities["area_search"] == row["district_name"])
        if row["city_name"] != "":
            cond = cond & (self._cities["city_search"] == row["city_name"])

        candidates = self._cities.loc[cond]
        if candidates.shape[0] == 1:
            result_row = candidates.iloc[0]
            return dict(
                region=result_row["region"],
                area=result_row["area"],
                city=result_row["city"],
                oktmo=result_row["oktmo"],
                method="a+c"
            )
        
        return None
    
    def _search_by_city(self, region_name, row):
        cond = (self._cities["region"] == region_name)
        if row["city_name"] != "":
            cond = cond & (self._cities["city_search"] == row["city_name"])
        else:
            return None

        candidates = self._cities.loc[cond]
        if candidates.shape[0] == 1:
            result_row = candidates.iloc[0]
            return dict(
                region=result_row["region"],
                area=result_row["area"],
                city=result_row["city"],
                oktmo=result_row["oktmo"],
                method="c"
            )
        
        return None
    
    def _search_by_area(self, region_name, row):
        cond = (self._cities["region"] == region_name)
        if row["district_name"] != "":
            cond = cond & (self._cities["area_search"] == row["district_name"])
        else:
            return None

        candidates = self._cities.loc[cond]
        if candidates.shape[0] == 1:
            result_row = candidates.iloc[0]
            return dict(
                region=result_row["region"],
                area=result_row["area"],
                city=result_row["city"],
                oktmo=result_row["oktmo"],
                method="a"
            )
        
        return None
    
    def _search_by_mun_and_settlement(self, region_name, row):
        cond = (self._settlements["region"] == region_name)
        if row["district_name"] != "":
            cond = cond & (self._settlements["municipality_search"] == row["district_name"])
        if row["settlement_name"] != "":
            cond = cond & (self._settlements["settlement_search"] == row["settlement_name"])

        candidates = self._settlements.loc[cond]
        if candidates.shape[0] == 1:
            result_row = candidates.iloc[0]
            return dict(
                region=result_row["region"],
                area=result_row["municipality"],
                city=result_row["settlement"],
                oktmo=result_row["oktmo"],
                method="m+s"
            )
        
        return None
        
    def _fuzzy_search_in_cities(self, region_name, row):
        candidates = self._cities.loc[self._cities["region"] == region_name.upper(), "area":"settlement_type"]
        if candidates.shape[0] == 0:
            return
        
        search = " ".join(row.to_list())
        candidates["score"] = candidates.apply(
            lambda x: fuzz.token_sort_ratio(" ".join(x.fillna("").to_list()), search),
            axis=1,
        )
        candidates = candidates.sort_values("score", ascending=False)
        return candidates
        
        if candidates.iloc[0]["score"] > self.THRES:
            result_row = candidates.iloc[0]
            return dict(
                region=result_row["region"],
                area=result_row["area"],
                city=result_row["city"],
                oktmo=result_row["oktmo"],
                method="f_c"
            )
        
    def _fuzzy_search_in_settlements(self, region_name, row):
        settlement_name = row["settlement_name"].upper()
        cond = (
            (self._settlements["region_name_search"] == str(region_name).upper())
            & (self._settlements["settlement_search"] == settlement_name)
        )
        candidates = self._settlements.loc[cond, "municipality":"settlement"]
        if candidates.shape[0] == 0:
            return
        
        search = f"{row['district_name']} {row['city_name']} {row['settlement_name']}"
        candidates["score"] = candidates.apply(
            lambda x: fuzz.token_sort_ratio(" ".join(x.fillna("").to_list()), search),
            axis=1,
        )
        candidates = candidates.sort_values("score", ascending=False)
        print(candidates)
        
        if candidates.iloc[0]["score"] > self.THRES:
            result_row = candidates.iloc[0]
            return dict(
                #region=result_row["region"],
                area=result_row["municipality"],
                settlement=result_row["settlement"],
                #oktmo=result_row["oktmo"],
                method="f_s"
            )
    
    def process_address(self, row: pd.Series) -> dict:
        row = row["region_name":"settlement_type"].fillna("")

        cache_index = "_".join(row.to_list())
        cached_result = self._addresses_cache.get(cache_index)
        if cached_result:
            return cached_result
        
        region_norm = self._normalize_region(row["region_name"])
        
        # Apply different search methods until the result is found
        methods = (
            #self._search_by_area_and_city,
           # self._search_by_city,
            #self._search_by_area,
            #self._search_by_mun_and_settlement,
           # self._fuzzy_search_in_cities,
            self._fuzzy_search_in_settlements,
        )
        
        for method in methods:
            result = method(region_norm, row)
            if result is not None:
                return result

# %%
g = Geonormalizer()
